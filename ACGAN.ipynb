# %% [markdown]
# 0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral.

# %% [markdown]
# ##Importing Libraries

# %%
import numpy as np
import pandas as pd
from keras.layers import Input, Conv2D, LeakyReLU, Dropout, BatchNormalization, Flatten, Dense, Embedding, Reshape, Activation, Concatenate, Conv2DTranspose
from keras.models import Model
from keras.optimizers import Adam
from numpy.random import randn, randint
from matplotlib import pyplot as plt
from keras.models import save_model
from math import sqrt
from numpy import asarray
from numpy.random import randn
from keras.models import load_model

# %% [markdown]
# ##Loading and Preprocessing the dataset

# %%
def load_fer2013_dataset():
    data = pd.read_csv('fer_chnge.csv')
    # Extract pixel and emotion labels
    pixels = data['pixels'].values
    emotions = data['emotion'].values
    X = []
    y = []
    for pixel_sequence, emotion in zip(pixels, emotions):
        # Parse the pixel sequence string into a list of integers
        pixel_values = [int(pixel) for pixel in pixel_sequence.split()]
        # Ensure that the pixel values array matches the expected size (48x48 = 2304 pixels)
        if len(pixel_values) != 2304:
            continue  # Skip sequences that are not 48x48
        # Reshape the pixel values into a 48x48 grayscale image (1 channel)
        image_array = np.array(pixel_values, dtype=np.uint8).reshape(48, 48, 1)
        # Normalize pixel values to range [0, 1]
        image_array = image_array.astype('float32') / 255.0
        # Append the processed image array and corresponding emotion label to the lists
        X.append(image_array)
        y.append(emotion)
    # Convert the lists to numpy arrays
    X = np.array(X)
    y = np.array(y, dtype='int32')
    return (X, y)

# %% [markdown]
# ##Discriminator Model

# %%
def define_discriminator(input_shape=(48, 48, 1), n_classes=7):
    input_image = Input(shape=input_shape)
    fe = Conv2D(32, (3,3), strides=(2,2), padding='same')(input_image)
    fe = LeakyReLU(alpha=0.2)(fe)
    fe = Dropout(0.5)(fe)
    fe = Conv2D(64, (3,3),strides=(2,2), padding='same')(fe)
    fe = BatchNormalization()(fe)
    fe = LeakyReLU(alpha=0.2)(fe)
    fe = Dropout(0.5)(fe)
    fe = Conv2D(128, (3,3), strides=(2,2), padding='same')(fe)
    fe = BatchNormalization()(fe)
    fe = LeakyReLU(alpha=0.2)(fe)
    fe = Dropout(0.5)(fe)
    fe = Conv2D(256, (3,3), padding='same')(fe)
    fe = BatchNormalization()(fe)
    fe = LeakyReLU(alpha=0.2)(fe)
    fe = Dropout(0.5)(fe)
    fe = Flatten()(fe)
    out1 = Dense(1, activation='sigmoid')(fe)
    out2 = Dense(n_classes, activation='softmax')(fe)
    model = Model(input_image, [out1, out2])
    opt = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(loss=['binary_crossentropy', 'sparse_categorical_crossentropy'], optimizer=opt)
    return model
d=define_discriminator()
d.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 24, 24, 32)           320       ['input_1[0][0]']
#
#  leaky_re_lu (LeakyReLU)     (None, 24, 24, 32)           0         ['conv2d[0][0]']
#
#  dropout (Dropout)           (None, 24, 24, 32)           0         ['leaky_re_lu[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 12, 12, 64)           18496     ['dropout[0][0]']
#
#  batch_normalization (Batch  (None, 12, 12, 64)           256       ['conv2d_1[0][0]']
#  Normalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 12, 12, 64)           0         ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)         (None, 12, 12, 64)           0         ['leaky_re_lu_1[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 6, 6, 128)            73856     ['dropout_1[0][0]']
#
#  batch_normalization_1 (Bat  (None, 6, 6, 128)            512       ['conv2d_2[0][0]']
#  chNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 6, 6, 128)            0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 6, 6, 128)            0         ['leaky_re_lu_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 256)            295168    ['dropout_2[0][0]']
#
#  batch_normalization_2 (Bat  (None, 6, 6, 256)            1024      ['conv2d_3[0][0]']
#  chNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 6, 6, 256)            0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 6, 6, 256)            0         ['leaky_re_lu_3[0][0]']
#
#  flatten (Flatten)           (None, 9216)                 0         ['dropout_3[0][0]']
#
#  dense (Dense)               (None, 1)                    9217      ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 7)                    64519     ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 463368 (1.77 MB)
# Trainable params: 462472 (1.76 MB)
# Non-trainable params: 896 (3.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ##Generator Model

# %%
def define_generator(latent_dim, n_classes=7):
    input_label = Input(shape=(1,))
    li = Embedding(n_classes, 50)(input_label)
    n_nodes = 12 * 12
    li = Dense(n_nodes)(li)
    li = Reshape((12, 12, 1))(li)
    input_lat = Input(shape=(latent_dim,))
    n_nodes = 384 * 12 * 12
    gen = Dense(n_nodes)(input_lat)
    gen = Activation('relu')(gen)
    gen = Reshape((12, 12, 384))(gen)
    merge = Concatenate()([gen, li])
    gen = Conv2DTranspose(192, (5,5), strides=(2,2), padding='same')(merge)
    gen = BatchNormalization()(gen)
    gen = Activation('relu')(gen)
    gen = Conv2DTranspose(1, (5,5), strides=(2,2), padding='same')(gen)
    out_layer = Activation('tanh')(gen)
    model = Model([input_lat, input_label], out_layer)
    return model
g=define_discriminator()
g.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 48, 48, 1)]          0         []
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 32)           320       ['input_2[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 24, 24, 32)           0         ['conv2d_4[0][0]']
#
#  dropout_4 (Dropout)         (None, 24, 24, 32)           0         ['leaky_re_lu_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 64)           18496     ['dropout_4[0][0]']
#
#  batch_normalization_3 (Bat  (None, 12, 12, 64)           256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 12, 12, 64)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_5 (Dropout)         (None, 12, 12, 64)           0         ['leaky_re_lu_5[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 6, 6, 128)            73856     ['dropout_5[0][0]']
#
#  batch_normalization_4 (Bat  (None, 6, 6, 128)            512       ['conv2d_6[0][0]']
#  chNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 6, 6, 128)            0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 6, 6, 128)            0         ['leaky_re_lu_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 6, 6, 256)            295168    ['dropout_6[0][0]']
#
#  batch_normalization_5 (Bat  (None, 6, 6, 256)            1024      ['conv2d_7[0][0]']
#  chNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 6, 6, 256)            0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 6, 6, 256)            0         ['leaky_re_lu_7[0][0]']
#
#  flatten_1 (Flatten)         (None, 9216)                 0         ['dropout_7[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    9217      ['flatten_1[0][0]']
#
#  dense_3 (Dense)             (None, 7)                    64519     ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 463368 (1.77 MB)
# Trainable params: 462472 (1.76 MB)
# Non-trainable params: 896 (3.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ##GAN Model(D+G)

# %%
def define_gan(g_model, d_model):
    for layer in d_model.layers:
        if not isinstance(layer, BatchNormalization):
            layer.trainable = False
    gan_output = d_model(g_model.output)
    model = Model(g_model.input, gan_output)
    opt = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(loss=['binary_crossentropy', 'sparse_categorical_crossentropy'], optimizer=opt)
    return model

# %% [markdown]
# ##Generate fake samples

# %%
# use the generator to generate n fake examples, with class labels
def generate_fake_samples(generator, latent_dim, n_samples, n_classes=7):
    z_input = np.random.randn(latent_dim * n_samples)
    z_input = z_input.reshape(n_samples, latent_dim)
    labels = np.random.randint(0, n_classes, n_samples).reshape(-1, 1)
    X_fake = generator.predict([z_input, labels])
    return X_fake, labels

# %% [markdown]
# ##Train the GAN

# %%
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs, n_batch):
    X_train, y_train = dataset
    bat_per_epo = 42
    for epoch in range(1, n_epochs + 1):
        print(f"Epoch {epoch}/{n_epochs}")

        for batch in range(bat_per_epo):
            ix = np.random.randint(0, X_train.shape[0], n_batch)
            X_real, labels_real = X_train[ix], y_train[ix]
            y_real = np.ones((n_batch, 1))
            _, d_r1, d_r2 = d_model.train_on_batch(X_real, [y_real, labels_real])

            X_fake, labels_fake = generate_fake_samples(g_model, latent_dim, n_batch)
            y_fake = np.zeros((n_batch, 1))
            _, d_f, d_f2 = d_model.train_on_batch(X_fake, [y_fake, labels_fake])

            z_input = np.random.randn(n_batch * latent_dim)
            z_input = z_input.reshape(n_batch, latent_dim)
            z_labels = np.random.randint(0, 7, n_batch).reshape(-1, 1)
            y_gan = np.ones((n_batch, 1))
            _, g_1, g_2 = gan_model.train_on_batch([z_input, z_labels], [y_gan, z_labels])

            print(f"  Batch {batch + 1}/{bat_per_epo}, d_real_loss: {d_r1:.4f}, d_real_acc: {d_r2:.4f}, "
                  f"d_fake_loss: {d_f:.4f}, d_fake_acc: {d_f2:.4f}, g_loss: {g_1:.4f}, g_acc: {g_2:.4f}")

        # Save generated images every few epochs
        if epoch % 100 == 0:
          examples=10
          latent_dim=100
          latent_points = np.random.randn(examples * latent_dim)
          latent_points = latent_points.reshape(examples, latent_dim)
          labels = np.random.randint(0, 7, examples).reshape(-1, 1)
          X_fake = g_model.predict([latent_points, labels])
          plt.figure(figsize=(10, 10))
          for i in range(examples):
            plt.subplot(1, examples, i + 1)
            plt.imshow(X_fake[i].reshape(48, 48), cmap='gray')
            plt.title('Label: %d' % labels[i])
            plt.axis('off')
          filename = 'generated_plot_epoch_%04d.png' % (epoch)
          plt.savefig(filename)
          plt.close()

# %% [markdown]
# ##Run the GAN

# %%
def run_cgan():
    dataset = load_fer2013_dataset()
    X_train, y_train = dataset
    d_model = define_discriminator(input_shape=(48, 48, 1))
    g_model = define_generator(latent_dim=100)
    gan_model = define_gan(g_model, d_model)
    train(g_model, d_model, gan_model, (X_train, y_train), latent_dim=100, n_epochs=500, n_batch=64)
    save_model(d_model, 'discriminator_model.h5')  # Save discriminator model
    # Save generator model
    save_model(g_model, 'generator_model.h5')  # Save generator model
    # Save GAN model (including both generator and discriminator)
    save_model(gan_model, 'acgan_model.h5')  # Save CGAN model
run_cgan()
# Out:
# Epoch 1/500
# 2/2 [==============================] - 1s 433ms/step
#   Batch 1/42, d_real_loss: 1.3709, d_real_acc: 2.3373, d_fake_loss: 0.7457, d_fake_acc: 2.6671, g_loss: 1.0247, g_acc: 2.8267
# 2/2 [==============================] - 1s 674ms/step
#   Batch 2/42, d_real_loss: 1.0934, d_real_acc: 2.4909, d_fake_loss: 0.9252, d_fake_acc: 2.8687, g_loss: 0.9025, g_acc: 2.7391
# 2/2 [==============================] - 1s 403ms/step
#   Batch 3/42, d_real_loss: 0.8922, d_real_acc: 2.5437, d_fake_loss: 1.0721, d_fake_acc: 2.5381, g_loss: 0.8822, g_acc: 2.7842
# 2/2 [==============================] - 1s 418ms/step
#   Batch 4/42, d_real_loss: 0.8818, d_real_acc: 2.9179, d_fake_loss: 0.9610, d_fake_acc: 2.6372, g_loss: 0.8779, g_acc: 3.0088
# 2/2 [==============================] - 1s 696ms/step
#   Batch 5/42, d_real_loss: 0.8215, d_real_acc: 2.7188, d_fake_loss: 0.9943, d_fake_acc: 2.7340, g_loss: 1.1860, g_acc: 2.6298
# 2/2 [==============================] - 1s 429ms/step
#   Batch 6/42, d_real_loss: 0.8961, d_real_acc: 2.8228, d_fake_loss: 0.8976, d_fake_acc: 2.7548, g_loss: 1.1335, g_acc: 2.5332
# 2/2 [==============================] - 1s 423ms/step
#   Batch 7/42, d_real_loss: 0.8879, d_real_acc: 2.4094, d_fake_loss: 0.8601, d_fake_acc: 2.8762, g_loss: 1.0273, g_acc: 2.6502
# 2/2 [==============================] - 1s 701ms/step
#   Batch 8/42, d_real_loss: 0.7854, d_real_acc: 2.5961, d_fake_loss: 0.8992, d_fake_acc: 2.9482, g_loss: 1.0730, g_acc: 2.5556
# 2/2 [==============================] - 1s 410ms/step
#   Batch 9/42, d_real_loss: 0.8476, d_real_acc: 2.1015, d_fake_loss: 0.8360, d_fake_acc: 2.4726, g_loss: 1.1740, g_acc: 2.6089
# 2/2 [==============================] - 1s 434ms/step
#   Batch 10/42, d_real_loss: 0.8374, d_real_acc: 2.1174, d_fake_loss: 0.7101, d_fake_acc: 2.7351, g_loss: 1.2010, g_acc: 2.7764
# 2/2 [==============================] - 1s 704ms/step
#   Batch 11/42, d_real_loss: 0.7295, d_real_acc: 2.5377, d_fake_loss: 0.8621, d_fake_acc: 2.6182, g_loss: 1.0834, g_acc: 2.4370
# 2/2 [==============================] - 1s 441ms/step
#   Batch 12/42, d_real_loss: 0.9491, d_real_acc: 2.6494, d_fake_loss: 0.7005, d_fake_acc: 2.6451, g_loss: 0.8564, g_acc: 2.5377
# 2/2 [==============================] - 1s 422ms/step
#   Batch 13/42, d_real_loss: 0.7202, d_real_acc: 2.4847, d_fake_loss: 0.7580, d_fake_acc: 2.8704, g_loss: 0.9931, g_acc: 2.5600
# 2/2 [==============================] - 1s 688ms/step
#   Batch 14/42, d_real_loss: 0.6515, d_real_acc: 2.4534, d_fake_loss: 1.0080, d_fake_acc: 2.5431, g_loss: 0.9317, g_acc: 2.3945
# 2/2 [==============================] - 1s 422ms/step
#   Batch 15/42, d_real_loss: 0.7503, d_real_acc: 2.5528, d_fake_loss: 0.8120, d_fake_acc: 2.5125, g_loss: 0.9371, g_acc: 2.8310
# 2/2 [==============================] - 1s 421ms/step
#   Batch 16/42, d_real_loss: 0.7966, d_real_acc: 2.4018, d_fake_loss: 0.8502, d_fake_acc: 2.8193, g_loss: 1.2508, g_acc: 2.6750
# 2/2 [==============================] - 1s 473ms/step
#   Batch 17/42, d_real_loss: 0.7421, d_real_acc: 2.3393, d_fake_loss: 0.7967, d_fake_acc: 3.0913, g_loss: 0.9344, g_acc: 2.8317
# 2/2 [==============================] - 1s 432ms/step
#   Batch 18/42, d_real_loss: 0.7493, d_real_acc: 2.4215, d_fake_loss: 0.8644, d_fake_acc: 2.9340, g_loss: 1.1612, g_acc: 2.5928
# 2/2 [==============================] - 1s 411ms/step
#   Batch 19/42, d_real_loss: 0.7235, d_real_acc: 2.3825, d_fake_loss: 0.7386, d_fake_acc: 2.5554, g_loss: 1.1991, g_acc: 2.7776
# 2/2 [==============================] - 1s 432ms/step
#   Batch 20/42, d_real_loss: 0.8287, d_real_acc: 2.2461, d_fake_loss: 0.8665, d_fake_acc: 2.7459, g_loss: 1.1988, g_acc: 2.5256
# 2/2 [==============================] - 1s 419ms/step
#   Batch 21/42, d_real_loss: 0.8180, d_real_acc: 2.3221, d_fake_loss: 0.7413, d_fake_acc: 2.8623, g_loss: 1.3233, g_acc: 2.7470
# 2/2 [==============================] - 1s 404ms/step
#   Batch 22/42, d_real_loss: 0.8765, d_real_acc: 2.4049, d_fake_loss: 0.8654, d_fake_acc: 2.5801, g_loss: 0.9860, g_acc: 2.6858
# 2/2 [==============================] - 1s 437ms/step
#   Batch 23/42, d_real_loss: 0.8150, d_real_acc: 2.7272, d_fake_loss: 0.9800, d_fake_acc: 2.7376, g_loss: 0.9767, g_acc: 2.7608
# 2/2 [==============================] - 1s 530ms/step
#   Batch 24/42, d_real_loss: 0.8638, d_real_acc: 2.3662, d_fake_loss: 0.9291, d_fake_acc: 2.6265, g_loss: 1.1800, g_acc: 2.8577
# 2/2 [==============================] - 1s 416ms/step
#   Batch 25/42, d_real_loss: 0.9435, d_real_acc: 2.4958, d_fake_loss: 1.0252, d_fake_acc: 2.5524, g_loss: 1.0134, g_acc: 3.0285
# 2/2 [==============================] - 1s 422ms/step
#   Batch 26/42, d_real_loss: 1.0243, d_real_acc: 2.3552, d_fake_loss: 0.9924, d_fake_acc: 2.7778, g_loss: 0.8787, g_acc: 2.5265
# 2/2 [==============================] - 1s 698ms/step
#   Batch 27/42, d_real_loss: 1.0168, d_real_acc: 2.6480, d_fake_loss: 0.9495, d_fake_acc: 2.6742, g_loss: 0.8615, g_acc: 2.5522
# 2/2 [==============================] - 1s 435ms/step
#   Batch 28/42, d_real_loss: 1.0280, d_real_acc: 2.4540, d_fake_loss: 1.1730, d_fake_acc: 2.7613, g_loss: 0.9302, g_acc: 2.8472
# 2/2 [==============================] - 1s 434ms/step
#   Batch 29/42, d_real_loss: 0.9209, d_real_acc: 2.4056, d_fake_loss: 0.9853, d_fake_acc: 2.5395, g_loss: 1.0347, g_acc: 2.6062
# 2/2 [==============================] - 1s 410ms/step
#   Batch 30/42, d_real_loss: 0.8968, d_real_acc: 2.8070, d_fake_loss: 1.0160, d_fake_acc: 2.3738, g_loss: 0.9302, g_acc: 2.3454
# 2/2 [==============================] - 1s 425ms/step
#   Batch 31/42, d_real_loss: 1.0261, d_real_acc: 2.6569, d_fake_loss: 0.7199, d_fake_acc: 2.4985, g_loss: 0.9965, g_acc: 2.3299
# 2/2 [==============================] - 1s 419ms/step
#   Batch 32/42, d_real_loss: 0.9071, d_real_acc: 2.6067, d_fake_loss: 0.8010, d_fake_acc: 2.9126, g_loss: 0.9803, g_acc: 2.8286
# 2/2 [==============================] - 1s 677ms/step
#   Batch 33/42, d_real_loss: 1.0219, d_real_acc: 2.3056, d_fake_loss: 0.8065, d_fake_acc: 2.6681, g_loss: 0.9132, g_acc: 2.5531
# 2/2 [==============================] - 1s 414ms/step
#   Batch 34/42, d_real_loss: 0.9642, d_real_acc: 2.5993, d_fake_loss: 0.9393, d_fake_acc: 2.7488, g_loss: 0.8876, g_acc: 2.6106
# 2/2 [==============================] - 1s 412ms/step
#   Batch 35/42, d_real_loss: 0.9703, d_real_acc: 2.5070, d_fake_loss: 0.9643, d_fake_acc: 2.4291, g_loss: 0.7283, g_acc: 2.6721
# 2/2 [==============================] - 1s 683ms/step
#   Batch 36/42, d_real_loss: 0.9267, d_real_acc: 2.3647, d_fake_loss: 0.9397, d_fake_acc: 2.6333, g_loss: 0.8448, g_acc: 2.4870
# 2/2 [==============================] - 1s 432ms/step
#   Batch 37/42, d_real_loss: 0.9214, d_real_acc: 2.1586, d_fake_loss: 1.1058, d_fake_acc: 2.6207, g_loss: 0.8904, g_acc: 2.2896
# 2/2 [==============================] - 1s 440ms/step
#   Batch 38/42, d_real_loss: 1.0072, d_real_acc: 2.5317, d_fake_loss: 0.6162, d_fake_acc: 2.8478, g_loss: 0.8041, g_acc: 2.7126
# 2/2 [==============================] - 1s 411ms/step
#   Batch 39/42, d_real_loss: 0.7926, d_real_acc: 2.3355, d_fake_loss: 0.7500, d_fake_acc: 2.6258, g_loss: 0.8613, g_acc: 2.7067
# 2/2 [==============================] - 1s 427ms/step
#   Batch 40/42, d_real_loss: 0.8212, d_real_acc: 2.4120, d_fake_loss: 0.7254, d_fake_acc: 2.5143, g_loss: 0.8134, g_acc: 2.5408
# 2/2 [==============================] - 1s 425ms/step
#   Batch 41/42, d_real_loss: 0.8205, d_real_acc: 2.6175, d_fake_loss: 0.9014, d_fake_acc: 2.2922, g_loss: 0.6227, g_acc: 2.5778
# 2/2 [==============================] - 1s 703ms/step
#   Batch 42/42, d_real_loss: 0.8912, d_real_acc: 2.5237, d_fake_loss: 0.7799, d_fake_acc: 2.7997, g_loss: 0.9393, g_acc: 2.5758
# Epoch 2/500
# 2/2 [==============================] - 1s 408ms/step
#   Batch 1/42, d_real_loss: 0.7524, d_real_acc: 2.5021, d_fake_loss: 0.6303, d_fake_acc: 2.2752, g_loss: 0.7807, g_acc: 2.8246
# 2/2 [==============================] - 1s 397ms/step
#   Batch 2/42, d_real_loss: 0.8184, d_real_acc: 2.2770, d_fake_loss: 0.6099, d_fake_acc: 2.7931, g_loss: 0.6683, g_acc: 2.8528
# 2/2 [==============================] - 1s 707ms/step
#   Batch 3/42, d_real_loss: 0.7667, d_real_acc: 2.1870, d_fake_loss: 0.7345, d_fake_acc: 2.4644, g_loss: 0.8488, g_acc: 2.5317
# 2/2 [==============================] - 1s 414ms/step
#   Batch 4/42, d_real_loss: 0.7593, d_real_acc: 2.4280, d_fake_loss: 0.8710, d_fake_acc: 2.9343, g_loss: 0.7462, g_acc: 2.7147
# 2/2 [==============================] - 1s 410ms/step
#   Batch 5/42, d_real_loss: 0.6867, d_real_acc: 2.2263, d_fake_loss: 0.7781, d_fake_acc: 2.6210, g_loss: 0.7128, g_acc: 2.3913
# 2/2 [==============================] - 1s 705ms/step
#   Batch 6/42, d_real_loss: 0.7424, d_real_acc: 2.2670, d_fake_loss: 0.7660, d_fake_acc: 3.0058, g_loss: 0.7330, g_acc: 2.7186
# 2/2 [==============================] - 1s 422ms/step
#   Batch 7/42, d_real_loss: 0.8345, d_real_acc: 2.5001, d_fake_loss: 0.5813, d_fake_acc: 2.7221, g_loss: 0.6263, g_acc: 2.2604
# 2/2 [==============================] - 1s 403ms/step
#   Batch 8/42, d_real_loss: 0.6048, d_real_acc: 2.5465, d_fake_loss: 0.6326, d_fake_acc: 2.4003, g_loss: 0.6675, g_acc: 2.7193
# 2/2 [==============================] - 1s 415ms/step
#   Batch 9/42, d_real_loss: 0.6802, d_real_acc: 2.1836, d_fake_loss: 0.6691, d_fake_acc: 2.5596, g_loss: 0.7641, g_acc: 2.6756
# 2/2 [==============================] - 1s 405ms/step
#   Batch 10/42, d_real_loss: 0.6251, d_real_acc: 2.2370, d_fake_loss: 0.4742, d_fake_acc: 2.6839, g_loss: 0.7721, g_acc: 2.5137
# 2/2 [==============================] - 1s 405ms/step
#   Batch 11/42, d_real_loss: 0.7176, d_real_acc: 2.3648, d_fake_loss: 0.6500, d_fake_acc: 2.5014, g_loss: 0.6769, g_acc: 2.4995
# 2/2 [==============================] - 1s 420ms/step
#   Batch 12/42, d_real_loss: 0.5884, d_real_acc: 2.2878, d_fake_loss: 0.5380, d_fake_acc: 2.5943, g_loss: 0.5851, g_acc: 2.3399
# 2/2 [==============================] - 1s 454ms/step
#   Batch 13/42, d_real_loss: 0.5063, d_real_acc: 2.0878, d_fake_loss: 0.7145, d_fake_acc: 2.5958, g_loss: 0.5943, g_acc: 2.3240
# 2/2 [==============================] - 1s 415ms/step
#   Batch 14/42, d_real_loss: 0.6665, d_real_acc: 2.3039, d_fake_loss: 0.6672, d_fake_acc: 2.5964, g_loss: 0.5062, g_acc: 2.7524
# 2/2 [==============================] - 1s 404ms/step
#   Batch 15/42, d_real_loss: 0.5892, d_real_acc: 2.3680, d_fake_loss: 0.6186, d_fake_acc: 2.6244, g_loss: 0.5662, g_acc: 2.9588
# 2/2 [==============================] - 1s 696ms/step
#   Batch 16/42, d_real_loss: 0.6324, d_real_acc: 2.5602, d_fake_loss: 0.4058, d_fake_acc: 2.5213, g_loss: 0.5242, g_acc: 2.5625
# 2/2 [==============================] - 1s 396ms/step
#   Batch 17/42, d_real_loss: 0.7585, d_real_acc: 2.2228, d_fake_loss: 0.3747, d_fake_acc: 2.3595, g_loss: 0.5340, g_acc: 2.6951
# 2/2 [==============================] - 1s 406ms/step
#   Batch 18/42, d_real_loss: 0.5109, d_real_acc: 2.1911, d_fake_loss: 0.4912, d_fake_acc: 2.2899, g_loss: 0.3592, g_acc: 2.7581
# 2/2 [==============================] - 1s 675ms/step
#   Batch 19/42, d_real_loss: 0.3593, d_real_acc: 2.3364, d_fake_loss: 0.5695, d_fake_acc: 2.4963, g_loss: 0.5258, g_acc: 2.7080
# 2/2 [==============================] - 1s 397ms/step
#   Batch 20/42, d_real_loss: 0.3829, d_real_acc: 2.2384, d_fake_loss: 0.3919, d_fake_acc: 2.5412, g_loss: 0.4495, g_acc: 2.5335
# 2/2 [==============================] - 1s 412ms/step
#   Batch 21/42, d_real_loss: 0.6141, d_real_acc: 2.2731, d_fake_loss: 0.3537, d_fake_acc: 2.3161, g_loss: 0.4161, g_acc: 2.7924
# 2/2 [==============================] - 1s 696ms/step
#   Batch 22/42, d_real_loss: 0.4619, d_real_acc: 2.3757, d_fake_loss: 0.3875, d_fake_acc: 2.7647, g_loss: 0.4817, g_acc: 2.8737
# 2/2 [==============================] - 1s 429ms/step
#   Batch 23/42, d_real_loss: 0.3851, d_real_acc: 2.4880, d_fake_loss: 0.4548, d_fake_acc: 2.7234, g_loss: 0.4363, g_acc: 2.7641
# 2/2 [==============================] - 1s 411ms/step
#   Batch 24/42, d_real_loss: 0.5390, d_real_acc: 2.3614, d_fake_loss: 0.4043, d_fake_acc: 2.2441, g_loss: 0.3691, g_acc: 2.5005
# 2/2 [==============================] - 1s 689ms/step
#   Batch 25/42, d_real_loss: 0.3803, d_real_acc: 2.5004, d_fake_loss: 0.4232, d_fake_acc: 2.2399, g_loss: 0.3396, g_acc: 2.6526
# 2/2 [==============================] - 1s 399ms/step
#   Batch 26/42, d_real_loss: 0.3463, d_real_acc: 2.4172, d_fake_loss: 0.3271, d_fake_acc: 2.8047, g_loss: 0.4013, g_acc: 2.4309
# 2/2 [==============================] - 1s 398ms/step
#   Batch 27/42, d_real_loss: 0.4235, d_real_acc: 2.1342, d_fake_loss: 0.3347, d_fake_acc: 2.7083, g_loss: 0.2849, g_acc: 2.5694
# 2/2 [==============================] - 1s 391ms/step
#   Batch 28/42, d_real_loss: 0.3324, d_real_acc: 2.3913, d_fake_loss: 0.4279, d_fake_acc: 2.5992, g_loss: 0.2919, g_acc: 2.7789
# 2/2 [==============================] - 1s 421ms/step
#   Batch 29/42, d_real_loss: 0.3392, d_real_acc: 2.3260, d_fake_loss: 0.3117, d_fake_acc: 2.3798, g_loss: 0.2987, g_acc: 2.9008
# 2/2 [==============================] - 1s 414ms/step
#   Batch 30/42, d_real_loss: 0.4052, d_real_acc: 2.4550, d_fake_loss: 0.3158, d_fake_acc: 2.4555, g_loss: 0.3292, g_acc: 2.4761
# 2/2 [==============================] - 1s 402ms/step
#   Batch 31/42, d_real_loss: 0.3273, d_real_acc: 2.2275, d_fake_loss: 0.2735, d_fake_acc: 2.5053, g_loss: 0.2772, g_acc: 2.5769
# 2/2 [==============================] - 1s 424ms/step
#   Batch 32/42, d_real_loss: 0.2856, d_real_acc: 2.2354, d_fake_loss: 0.4068, d_fake_acc: 2.4301, g_loss: 0.3269, g_acc: 2.9448
# 2/2 [==============================] - 1s 390ms/step
#   Batch 33/42, d_real_loss: 0.3666, d_real_acc: 2.1500, d_fake_loss: 0.3762, d_fake_acc: 2.8714, g_loss: 0.3335, g_acc: 2.3936
# 2/2 [==============================] - 1s 398ms/step
#   Batch 34/42, d_real_loss: 0.2760, d_real_acc: 2.1682, d_fake_loss: 0.2284, d_fake_acc: 2.4243, g_loss: 0.3590, g_acc: 2.8114
# 2/2 [==============================] - 1s 630ms/step
#   Batch 35/42, d_real_loss: 0.3727, d_real_acc: 2.3427, d_fake_loss: 0.2663, d_fake_acc: 2.3320, g_loss: 0.2198, g_acc: 2.6065
# 2/2 [==============================] - 1s 392ms/step
#   Batch 36/42, d_real_loss: 0.3103, d_real_acc: 2.1746, d_fake_loss: 0.2561, d_fake_acc: 2.2710, g_loss: 0.2091, g_acc: 2.7869
# 2/2 [==============================] - 1s 408ms/step
#   Batch 37/42, d_real_loss: 0.3313, d_real_acc: 2.2414, d_fake_loss: 0.1844, d_fake_acc: 2.4702, g_loss: 0.1748, g_acc: 2.7353
# 2/2 [==============================] - 1s 664ms/step
#   Batch 38/42, d_real_loss: 0.2269, d_real_acc: 1.9907, d_fake_loss: 0.1908, d_fake_acc: 2.5384, g_loss: 0.1663, g_acc: 2.4119
# 2/2 [==============================] - 1s 400ms/step
#   Batch 39/42, d_real_loss: 0.2343, d_real_acc: 2.3570, d_fake_loss: 0.2628, d_fake_acc: 2.4154, g_loss: 0.1938, g_acc: 2.4534
# 2/2 [==============================] - 1s 401ms/step
#   Batch 40/42, d_real_loss: 0.2208, d_real_acc: 2.3700, d_fake_loss: 0.1847, d_fake_acc: 2.3764, g_loss: 0.2301, g_acc: 2.5340
# 2/2 [==============================] - 1s 703ms/step
#   Batch 41/42, d_real_loss: 0.1546, d_real_acc: 2.3761, d_fake_loss: 0.1202, d_fake_acc: 2.5961, g_loss: 0.1739, g_acc: 2.5360
# 2/2 [==============================] - 1s 408ms/step
#   Batch 42/42, d_real_loss: 0.2150, d_real_acc: 2.1743, d_fake_loss: 0.1622, d_fake_acc: 2.5511, g_loss: 0.1837, g_acc: 2.8415
# Epoch 3/500
# 2/2 [==============================] - 1s 408ms/step
#   Batch 1/42, d_real_loss: 0.1922, d_real_acc: 2.2183, d_fake_loss: 0.1748, d_fake_acc: 2.3290, g_loss: 0.2092, g_acc: 2.6429
# 2/2 [==============================] - 1s 473ms/step
#   Batch 2/42, d_real_loss: 0.2031, d_real_acc: 1.9776, d_fake_loss: 0.1552, d_fake_acc: 2.3407, g_loss: 0.1806, g_acc: 2.5243
# 2/2 [==============================] - 1s 405ms/step
#   Batch 3/42, d_real_loss: 0.2074, d_real_acc: 2.4714, d_fake_loss: 0.1877, d_fake_acc: 2.8761, g_loss: 0.1455, g_acc: 2.5540
# 2/2 [==============================] - 1s 415ms/step
#   Batch 4/42, d_real_loss: 0.2245, d_real_acc: 2.3783, d_fake_loss: 0.1158, d_fake_acc: 2.6150, g_loss: 0.1381, g_acc: 2.4454
# 2/2 [==============================] - 1s 401ms/step
#   Batch 5/42, d_real_loss: 0.1312, d_real_acc: 2.3956, d_fake_loss: 0.1586, d_fake_acc: 2.4168, g_loss: 0.1506, g_acc: 2.5498
# 2/2 [==============================] - 1s 400ms/step
#   Batch 6/42, d_real_loss: 0.1720, d_real_acc: 2.4009, d_fake_loss: 0.1935, d_fake_acc: 2.2614, g_loss: 0.1666, g_acc: 2.5491
# 2/2 [==============================] - 1s 420ms/step
#   Batch 7/42, d_real_loss: 0.1424, d_real_acc: 2.2848, d_fake_loss: 0.0934, d_fake_acc: 2.4953, g_loss: 0.2043, g_acc: 2.4686
# 2/2 [==============================] - 1s 399ms/step
#   Batch 8/42, d_real_loss: 0.1290, d_real_acc: 2.4553, d_fake_loss: 0.0990, d_fake_acc: 2.6332, g_loss: 0.1705, g_acc: 2.5377
# 2/2 [==============================] - 1s 409ms/step
#   Batch 9/42, d_real_loss: 0.1001, d_real_acc: 2.3383, d_fake_loss: 0.1214, d_fake_acc: 2.4769, g_loss: 0.1768, g_acc: 2.7535
# 2/2 [==============================] - 1s 431ms/step
#   Batch 10/42, d_real_loss: 0.1420, d_real_acc: 2.1191, d_fake_loss: 0.1166, d_fake_acc: 2.5468, g_loss: 0.1278, g_acc: 2.5833
# 2/2 [==============================] - 1s 427ms/step
#   Batch 11/42, d_real_loss: 0.1183, d_real_acc: 2.0967, d_fake_loss: 0.1186, d_fake_acc: 2.6376, g_loss: 0.0998, g_acc: 2.8814
# 2/2 [==============================] - 1s 415ms/step
#   Batch 12/42, d_real_loss: 0.1303, d_real_acc: 2.5822, d_fake_loss: 0.0610, d_fake_acc: 2.7417, g_loss: 0.1416, g_acc: 2.7052
# 2/2 [==============================] - 1s 424ms/step
#   Batch 13/42, d_real_loss: 0.1291, d_real_acc: 1.9883, d_fake_loss: 0.0582, d_fake_acc: 2.4127, g_loss: 0.1216, g_acc: 2.7271
# 2/2 [==============================] - 1s 424ms/step
#   Batch 14/42, d_real_loss: 0.1549, d_real_acc: 1.9904, d_fake_loss: 0.1573, d_fake_acc: 2.6999, g_loss: 0.1214, g_acc: 2.3552
# 2/2 [==============================] - 1s 430ms/step
#   Batch 15/42, d_real_loss: 0.0990, d_real_acc: 2.3388, d_fake_loss: 0.0992, d_fake_acc: 2.5425, g_loss: 0.0967, g_acc: 2.5705
# 2/2 [==============================] - 1s 404ms/step
#   Batch 16/42, d_real_loss: 0.0942, d_real_acc: 2.5506, d_fake_loss: 0.1046, d_fake_acc: 2.4213, g_loss: 0.0963, g_acc: 2.7488
# 2/2 [==============================] - 1s 404ms/step
#   Batch 17/42, d_real_loss: 0.1147, d_real_acc: 2.2716, d_fake_loss: 0.0882, d_fake_acc: 2.6345, g_loss: 0.0772, g_acc: 2.8180
# 2/2 [==============================] - 1s 625ms/step
#   Batch 18/42, d_real_loss: 0.0784, d_real_acc: 2.1107, d_fake_loss: 0.1210, d_fake_acc: 2.5476, g_loss: 0.1479, g_acc: 2.7394
# 2/2 [==============================] - 1s 397ms/step
#   Batch 19/42, d_real_loss: 0.0921, d_real_acc: 2.2215, d_fake_loss: 0.0665, d_fake_acc: 2.4779, g_loss: 0.0900, g_acc: 2.7403
# 2/2 [==============================] - 1s 410ms/step
#   Batch 20/42, d_real_loss: 0.1264, d_real_acc: 2.3537, d_fake_loss: 0.0778, d_fake_acc: 2.4440, g_loss: 0.0492, g_acc: 2.4937
# 2/2 [==============================] - 1s 401ms/step
#   Batch 21/42, d_real_loss: 0.0961, d_real_acc: 2.1444, d_fake_loss: 0.0886, d_fake_acc: 2.6889, g_loss: 0.0534, g_acc: 2.7849
# 2/2 [==============================] - 1s 404ms/step
#   Batch 22/42, d_real_loss: 0.0738, d_real_acc: 2.1960, d_fake_loss: 0.0731, d_fake_acc: 2.6807, g_loss: 0.0517, g_acc: 2.8932
# 2/2 [==============================] - 1s 421ms/step
#   Batch 23/42, d_real_loss: 0.0657, d_real_acc: 2.3826, d_fake_loss: 0.0482, d_fake_acc: 2.4704, g_loss: 0.0698, g_acc: 2.4931
# 2/2 [==============================] - 1s 679ms/step
#   Batch 24/42, d_real_loss: 0.1044, d_real_acc: 2.1454, d_fake_loss: 0.0729, d_fake_acc: 2.3595, g_loss: 0.0728, g_acc: 2.8413
# 2/2 [==============================] - 1s 413ms/step
#   Batch 25/42, d_real_loss: 0.0739, d_real_acc: 2.2586, d_fake_loss: 0.0525, d_fake_acc: 2.4673, g_loss: 0.0747, g_acc: 2.6242
# 2/2 [==============================] - 1s 413ms/step
#   Batch 26/42, d_real_loss: 0.0556, d_real_acc: 2.2818, d_fake_loss: 0.0496, d_fake_acc: 2.3594, g_loss: 0.0421, g_acc: 2.6245
# 2/2 [==============================] - 1s 457ms/step
#   Batch 27/42, d_real_loss: 0.0827, d_real_acc: 2.0562, d_fake_loss: 0.0724, d_fake_acc: 2.5140, g_loss: 0.0298, g_acc: 3.2235
# 2/2 [==============================] - 1s 409ms/step
#   Batch 28/42, d_real_loss: 0.0455, d_real_acc: 2.1390, d_fake_loss: 0.0463, d_fake_acc: 2.4550, g_loss: 0.0325, g_acc: 2.9746
# 2/2 [==============================] - 1s 412ms/step
#   Batch 29/42, d_real_loss: 0.0442, d_real_acc: 2.1934, d_fake_loss: 0.0382, d_fake_acc: 2.3560, g_loss: 0.0561, g_acc: 2.5314
# 2/2 [==============================] - 1s 404ms/step
#   Batch 30/42, d_real_loss: 0.0560, d_real_acc: 2.3738, d_fake_loss: 0.0337, d_fake_acc: 2.5988, g_loss: 0.0625, g_acc: 2.7582
# 2/2 [==============================] - 1s 700ms/step
#   Batch 31/42, d_real_loss: 0.0493, d_real_acc: 2.3435, d_fake_loss: 0.0272, d_fake_acc: 2.6086, g_loss: 0.0713, g_acc: 2.6206
# 2/2 [==============================] - 1s 410ms/step
#   Batch 32/42, d_real_loss: 0.0964, d_real_acc: 2.3059, d_fake_loss: 0.0306, d_fake_acc: 2.4857, g_loss: 0.1361, g_acc: 2.4348
# 2/2 [==============================] - 1s 411ms/step
#   Batch 33/42, d_real_loss: 0.0487, d_real_acc: 2.0652, d_fake_loss: 0.0433, d_fake_acc: 2.6458, g_loss: 0.1176, g_acc: 2.6079
# 2/2 [==============================] - 1s 679ms/step
#   Batch 34/42, d_real_loss: 0.0455, d_real_acc: 2.3304, d_fake_loss: 0.0207, d_fake_acc: 2.1980, g_loss: 0.0805, g_acc: 2.5590
# 2/2 [==============================] - 1s 413ms/step
#   Batch 35/42, d_real_loss: 0.0884, d_real_acc: 2.1919, d_fake_loss: 0.0461, d_fake_acc: 2.4401, g_loss: 0.0855, g_acc: 2.3649
# 2/2 [==============================] - 1s 423ms/step
#   Batch 36/42, d_real_loss: 0.0305, d_real_acc: 2.3669, d_fake_loss: 0.0469, d_fake_acc: 2.5712, g_loss: 0.0404, g_acc: 2.3118
# 2/2 [==============================] - 1s 633ms/step
#   Batch 37/42, d_real_loss: 0.0274, d_real_acc: 2.0196, d_fake_loss: 0.0353, d_fake_acc: 2.3596, g_loss: 0.0692, g_acc: 2.6794
# 2/2 [==============================] - 1s 407ms/step
#   Batch 38/42, d_real_loss: 0.0439, d_real_acc: 2.2379, d_fake_loss: 0.0331, d_fake_acc: 2.2628, g_loss: 0.0723, g_acc: 2.2708
# 2/2 [==============================] - 1s 415ms/step
#   Batch 39/42, d_real_loss: 0.0407, d_real_acc: 2.0731, d_fake_loss: 0.0388, d_fake_acc: 2.4769, g_loss: 0.0670, g_acc: 2.3234
# 2/2 [==============================] - 1s 403ms/step
#   Batch 40/42, d_real_loss: 0.0280, d_real_acc: 2.2774, d_fake_loss: 0.0587, d_fake_acc: 2.4065, g_loss: 0.0367, g_acc: 2.5561
# 2/2 [==============================] - 1s 407ms/step
#   Batch 41/42, d_real_loss: 0.0258, d_real_acc: 2.0614, d_fake_loss: 0.0285, d_fake_acc: 2.1054, g_loss: 0.0709, g_acc: 2.8549
# 2/2 [==============================] - 1s 420ms/step
#   Batch 42/42, d_real_loss: 0.0207, d_real_acc: 2.0437, d_fake_loss: 0.0204, d_fake_acc: 2.4636, g_loss: 0.0543, g_acc: 2.4876
# Epoch 4/500
# 2/2 [==============================] - 1s 407ms/step
#   Batch 1/42, d_real_loss: 0.0643, d_real_acc: 2.1972, d_fake_loss: 0.0441, d_fake_acc: 2.0958, g_loss: 0.1084, g_acc: 2.8135
# 2/2 [==============================] - 1s 481ms/step
#   Batch 2/42, d_real_loss: 0.0425, d_real_acc: 2.4060, d_fake_loss: 0.0448, d_fake_acc: 2.2810, g_loss: 0.0362, g_acc: 2.1632
# 2/2 [==============================] - 1s 411ms/step
#   Batch 3/42, d_real_loss: 0.0638, d_real_acc: 2.0066, d_fake_loss: 0.0270, d_fake_acc: 2.4854, g_loss: 0.0475, g_acc: 2.4967
# 2/2 [==============================] - 1s 414ms/step
#   Batch 4/42, d_real_loss: 0.0422, d_real_acc: 2.4566, d_fake_loss: 0.0227, d_fake_acc: 2.4055, g_loss: 0.0836, g_acc: 2.3323
# 2/2 [==============================] - 1s 672ms/step
#   Batch 5/42, d_real_loss: 0.0603, d_real_acc: 2.0894, d_fake_loss: 0.0399, d_fake_acc: 1.9709, g_loss: 0.0839, g_acc: 2.5672
# 2/2 [==============================] - 1s 413ms/step
#   Batch 6/42, d_real_loss: 0.0305, d_real_acc: 2.2116, d_fake_loss: 0.0142, d_fake_acc: 2.2825, g_loss: 0.1244, g_acc: 2.5006
# 2/2 [==============================] - 1s 407ms/step
#   Batch 7/42, d_real_loss: 0.0535, d_real_acc: 2.1390, d_fake_loss: 0.0265, d_fake_acc: 2.1726, g_loss: 0.0774, g_acc: 1.9931
# 2/2 [==============================] - 1s 680ms/step
#   Batch 8/42, d_real_loss: 0.0214, d_real_acc: 2.3180, d_fake_loss: 0.0382, d_fake_acc: 2.0380, g_loss: 0.0515, g_acc: 2.3651
# 2/2 [==============================] - 1s 407ms/step
#   Batch 9/42, d_real_loss: 0.0207, d_real_acc: 2.2309, d_fake_loss: 0.0260, d_fake_acc: 2.1372, g_loss: 0.0456, g_acc: 2.4330
# 2/2 [==============================] - 1s 432ms/step
#   Batch 10/42, d_real_loss: 0.0202, d_real_acc: 2.3350, d_fake_loss: 0.0247, d_fake_acc: 2.2156, g_loss: 0.1156, g_acc: 2.2775
# 2/2 [==============================] - 1s 704ms/step
#   Batch 11/42, d_real_loss: 0.0207, d_real_acc: 2.1048, d_fake_loss: 0.0306, d_fake_acc: 2.4336, g_loss: 0.0750, g_acc: 1.9863
# 2/2 [==============================] - 1s 400ms/step
#   Batch 12/42, d_real_loss: 0.0283, d_real_acc: 2.1687, d_fake_loss: 0.0257, d_fake_acc: 2.0050, g_loss: 0.0448, g_acc: 2.6050
# 2/2 [==============================] - 1s 400ms/step
#   Batch 13/42, d_real_loss: 0.0165, d_real_acc: 2.0555, d_fake_loss: 0.0354, d_fake_acc: 2.3649, g_loss: 0.0438, g_acc: 2.0716
# 2/2 [==============================] - 1s 409ms/step
#   Batch 14/42, d_real_loss: 0.0313, d_real_acc: 2.0606, d_fake_loss: 0.0276, d_fake_acc: 2.0144, g_loss: 0.0816, g_acc: 1.9816
# 2/2 [==============================] - 1s 419ms/step
#   Batch 15/42, d_real_loss: 0.0520, d_real_acc: 2.3085, d_fake_loss: 0.0225, d_fake_acc: 2.1865, g_loss: 0.0472, g_acc: 2.1633
# 2/2 [==============================] - 1s 409ms/step
#   Batch 16/42, d_real_loss: 0.0165, d_real_acc: 2.1989, d_fake_loss: 0.0321, d_fake_acc: 1.8985, g_loss: 0.0717, g_acc: 1.8072
# 2/2 [==============================] - 1s 409ms/step
#   Batch 17/42, d_real_loss: 0.0269, d_real_acc: 1.9250, d_fake_loss: 0.0274, d_fake_acc: 2.0139, g_loss: 0.0678, g_acc: 1.9070
# 2/2 [==============================] - 1s 695ms/step
#   Batch 18/42, d_real_loss: 0.0136, d_real_acc: 2.4325, d_fake_loss: 0.0256, d_fake_acc: 1.6601, g_loss: 0.0641, g_acc: 1.7674
# 2/2 [==============================] - 1s 399ms/step
#   Batch 19/42, d_real_loss: 0.0156, d_real_acc: 2.6428, d_fake_loss: 0.0319, d_fake_acc: 2.0187, g_loss: 0.0634, g_acc: 1.8010
# 2/2 [==============================] - 1s 420ms/step
#   Batch 20/42, d_real_loss: 0.0131, d_real_acc: 2.2058, d_fake_loss: 0.0228, d_fake_acc: 1.8727, g_loss: 0.1020, g_acc: 1.5267
# 2/2 [==============================] - 1s 682ms/step
#   Batch 21/42, d_real_loss: 0.0191, d_real_acc: 2.2950, d_fake_loss: 0.0308, d_fake_acc: 1.6048, g_loss: 0.0963, g_acc: 1.9168
# 2/2 [==============================] - 1s 407ms/step
#   Batch 22/42, d_real_loss: 0.0247, d_real_acc: 2.1983, d_fake_loss: 0.0282, d_fake_acc: 1.6982, g_loss: 0.0695, g_acc: 1.9117
# 2/2 [==============================] - 1s 403ms/step
#   Batch 23/42, d_real_loss: 0.0201, d_real_acc: 2.4765, d_fake_loss: 0.0285, d_fake_acc: 1.7666, g_loss: 0.0799, g_acc: 1.4561
# 2/2 [==============================] - 1s 576ms/step
#   Batch 24/42, d_real_loss: 0.0210, d_real_acc: 2.1430, d_fake_loss: 0.0396, d_fake_acc: 1.4233, g_loss: 0.0503, g_acc: 1.5442
# 2/2 [==============================] - 1s 417ms/step
#   Batch 25/42, d_real_loss: 0.0109, d_real_acc: 2.1683, d_fake_loss: 0.0554, d_fake_acc: 1.6553, g_loss: 0.0627, g_acc: 1.6043
# 2/2 [==============================] - 1s 657ms/step
#   Batch 26/42, d_real_loss: 0.0180, d_real_acc: 1.9276, d_fake_loss: 0.0457, d_fake_acc: 1.4811, g_loss: 0.0700, g_acc: 1.4039
# 2/2 [==============================] - 1s 686ms/step
#   Batch 27/42, d_real_loss: 0.0378, d_real_acc: 2.0602, d_fake_loss: 0.0250, d_fake_acc: 1.3282, g_loss: 0.1390, g_acc: 1.1490
# 2/2 [==============================] - 1s 418ms/step
#   Batch 28/42, d_real_loss: 0.0147, d_real_acc: 2.1002, d_fake_loss: 0.0221, d_fake_acc: 1.2573, g_loss: 0.0768, g_acc: 1.2535
# 2/2 [==============================] - 1s 415ms/step
#   Batch 29/42, d_real_loss: 0.0211, d_real_acc: 1.9823, d_fake_loss: 0.0516, d_fake_acc: 1.2121, g_loss: 0.0518, g_acc: 1.2779
# 2/2 [==============================] - 1s 418ms/step
#   Batch 30/42, d_real_loss: 0.0383, d_real_acc: 1.9910, d_fake_loss: 0.0304, d_fake_acc: 1.1928, g_loss: 0.0910, g_acc: 0.8934
# 2/2 [==============================] - 1s 403ms/step
#   Batch 31/42, d_real_loss: 0.0082, d_real_acc: 2.2544, d_fake_loss: 0.0350, d_fake_acc: 1.1716, g_loss: 0.1098, g_acc: 1.0232
# 2/2 [==============================] - 1s 420ms/step
#   Batch 32/42, d_real_loss: 0.0126, d_real_acc: 2.4555, d_fake_loss: 0.0360, d_fake_acc: 0.8143, g_loss: 0.1314, g_acc: 0.7296
# 2/2 [==============================] - 1s 411ms/step
#   Batch 33/42, d_real_loss: 0.0107, d_real_acc: 2.4898, d_fake_loss: 0.0559, d_fake_acc: 0.8670, g_loss: 0.1696, g_acc: 0.8499
# 2/2 [==============================] - 1s 677ms/step
#   Batch 34/42, d_real_loss: 0.0185, d_real_acc: 2.1579, d_fake_loss: 0.0726, d_fake_acc: 0.6338, g_loss: 0.0898, g_acc: 0.8964
# 2/2 [==============================] - 1s 404ms/step
#   Batch 35/42, d_real_loss: 0.0161, d_real_acc: 1.9215, d_fake_loss: 0.0359, d_fake_acc: 0.7497, g_loss: 0.1735, g_acc: 0.7091
# 2/2 [==============================] - 1s 413ms/step
#   Batch 36/42, d_real_loss: 0.0286, d_real_acc: 1.9762, d_fake_loss: 0.0922, d_fake_acc: 0.5654, g_loss: 0.0899, g_acc: 0.7754
# 2/2 [==============================] - 1s 688ms/step
#   Batch 37/42, d_real_loss: 0.0155, d_real_acc: 2.0513, d_fake_loss: 0.0416, d_fake_acc: 0.5995, g_loss: 0.0550, g_acc: 0.5633
# 2/2 [==============================] - 1s 405ms/step
#   Batch 38/42, d_real_loss: 0.0183, d_real_acc: 1.9036, d_fake_loss: 0.0306, d_fake_acc: 0.4932, g_loss: 0.1479, g_acc: 0.4071
# 2/2 [==============================] - 1s 396ms/step
#   Batch 39/42, d_real_loss: 0.0134, d_real_acc: 1.9178, d_fake_loss: 0.0847, d_fake_acc: 0.5707, g_loss: 0.0906, g_acc: 0.6728
# 2/2 [==============================] - 1s 677ms/step
#   Batch 40/42, d_real_loss: 0.0217, d_real_acc: 2.0147, d_fake_loss: 0.0260, d_fake_acc: 0.4436, g_loss: 0.1141, g_acc: 0.4309
# 2/2 [==============================] - 1s 406ms/step
#   Batch 41/42, d_real_loss: 0.0515, d_real_acc: 2.1382, d_fake_loss: 0.0324, d_fake_acc: 0.3129, g_loss: 0.1437, g_acc: 0.4202
# 2/2 [==============================] - 1s 400ms/step
#   Batch 42/42, d_real_loss: 0.0327, d_real_acc: 2.1133, d_fake_loss: 0.0374, d_fake_acc: 0.3600, g_loss: 0.1152, g_acc: 0.4417
# Epoch 5/500
# 2/2 [==============================] - 1s 406ms/step
#   Batch 1/42, d_real_loss: 0.0305, d_real_acc: 2.0630, d_fake_loss: 0.0503, d_fake_acc: 0.3474, g_loss: 0.1264, g_acc: 0.2994
# 2/2 [==============================] - 1s 431ms/step
#   Batch 2/42, d_real_loss: 0.0121, d_real_acc: 2.3129, d_fake_loss: 0.1252, d_fake_acc: 0.2857, g_loss: 0.1173, g_acc: 0.3376
# 2/2 [==============================] - 1s 402ms/step
#   Batch 3/42, d_real_loss: 0.0173, d_real_acc: 2.3596, d_fake_loss: 0.1092, d_fake_acc: 0.3300, g_loss: 0.1106, g_acc: 0.2497
# 2/2 [==============================] - 1s 395ms/step
#   Batch 4/42, d_real_loss: 0.1039, d_real_acc: 2.1503, d_fake_loss: 0.0708, d_fake_acc: 0.3244, g_loss: 0.0894, g_acc: 0.3566
# 2/2 [==============================] - 1s 408ms/step
#   Batch 5/42, d_real_loss: 0.0781, d_real_acc: 2.0740, d_fake_loss: 0.0351, d_fake_acc: 0.2519, g_loss: 0.1144, g_acc: 0.3245
# 2/2 [==============================] - 1s 408ms/step
#   Batch 6/42, d_real_loss: 0.0336, d_real_acc: 2.2885, d_fake_loss: 0.0301, d_fake_acc: 0.2299, g_loss: 0.0659, g_acc: 0.2502
# 2/2 [==============================] - 1s 396ms/step
#   Batch 7/42, d_real_loss: 0.0288, d_real_acc: 2.0151, d_fake_loss: 0.0304, d_fake_acc: 0.2243, g_loss: 0.1467, g_acc: 0.2857
# 2/2 [==============================] - 1s 684ms/step
#   Batch 8/42, d_real_loss: 0.0464, d_real_acc: 2.3450, d_fake_loss: 0.0626, d_fake_acc: 0.2802, g_loss: 0.1058, g_acc: 0.3108
# 2/2 [==============================] - 1s 411ms/step
#   Batch 9/42, d_real_loss: 0.0206, d_real_acc: 2.3281, d_fake_loss: 0.0772, d_fake_acc: 0.1766, g_loss: 0.0944, g_acc: 0.2141
# 2/2 [==============================] - 1s 399ms/step
#   Batch 10/42, d_real_loss: 0.0279, d_real_acc: 2.1954, d_fake_loss: 0.0362, d_fake_acc: 0.1702, g_loss: 0.1050, g_acc: 0.2939
# 2/2 [==============================] - 1s 505ms/step
#   Batch 11/42, d_real_loss: 0.0300, d_real_acc: 2.2473, d_fake_loss: 0.0502, d_fake_acc: 0.1684, g_loss: 0.1162, g_acc: 0.2848
# 2/2 [==============================] - 1s 421ms/step
#   Batch 12/42, d_real_loss: 0.0408, d_real_acc: 2.1023, d_fake_loss: 0.0541, d_fake_acc: 0.1713, g_loss: 0.0827, g_acc: 0.2501
# 2/2 [==============================] - 1s 409ms/step
#   Batch 13/42, d_real_loss: 0.0518, d_real_acc: 1.9598, d_fake_loss: 0.0738, d_fake_acc: 0.2245, g_loss: 0.1339, g_acc: 0.2933
# 2/2 [==============================] - 1s 404ms/step
#   Batch 14/42, d_real_loss: 0.0376, d_real_acc: 2.0437, d_fake_loss: 0.0600, d_fake_acc: 0.1300, g_loss: 0.1342, g_acc: 0.2055
# 2/2 [==============================] - 1s 426ms/step
#   Batch 15/42, d_real_loss: 0.0198, d_real_acc: 1.7683, d_fake_loss: 0.0488, d_fake_acc: 0.1559, g_loss: 0.2027, g_acc: 0.2481
# 2/2 [==============================] - 1s 416ms/step
#   Batch 16/42, d_real_loss: 0.0547, d_real_acc: 2.1344, d_fake_loss: 0.0785, d_fake_acc: 0.1478, g_loss: 0.0956, g_acc: 0.2639
# 2/2 [==============================] - 1s 422ms/step
#   Batch 17/42, d_real_loss: 0.0705, d_real_acc: 1.8484, d_fake_loss: 0.0692, d_fake_acc: 0.0958, g_loss: 0.1091, g_acc: 0.1805
# 2/2 [==============================] - 1s 747ms/step
#   Batch 18/42, d_real_loss: 0.0607, d_real_acc: 1.9986, d_fake_loss: 0.0442, d_fake_acc: 0.0970, g_loss: 0.1254, g_acc: 0.1568
# 2/2 [==============================] - 1s 422ms/step
#   Batch 19/42, d_real_loss: 0.0316, d_real_acc: 2.2353, d_fake_loss: 0.0601, d_fake_acc: 0.1160, g_loss: 0.1226, g_acc: 0.1710
# 2/2 [==============================] - 1s 423ms/step
#   Batch 20/42, d_real_loss: 0.0535, d_real_acc: 1.9707, d_fake_loss: 0.1273, d_fake_acc: 0.1784, g_loss: 0.0592, g_acc: 0.2300
# 2/2 [==============================] - 1s 704ms/step
#   Batch 21/42, d_real_loss: 0.1083, d_real_acc: 1.9879, d_fake_loss: 0.0252, d_fake_acc: 0.1000, g_loss: 0.1258, g_acc: 0.1519
# 2/2 [==============================] - 1s 428ms/step
#   Batch 22/42, d_real_loss: 0.0563, d_real_acc: 2.1891, d_fake_loss: 0.0319, d_fake_acc: 0.1030, g_loss: 0.1083, g_acc: 0.2076
# 2/2 [==============================] - 1s 419ms/step
#   Batch 23/42, d_real_loss: 0.0625, d_real_acc: 2.0292, d_fake_loss: 0.0226, d_fake_acc: 0.1249, g_loss: 0.1030, g_acc: 0.2083
# 2/2 [==============================] - 1s 432ms/step
#   Batch 24/42, d_real_loss: 0.0891, d_real_acc: 1.8510, d_fake_loss: 0.0396, d_fake_acc: 0.1534, g_loss: 0.1558, g_acc: 0.1448
# 2/2 [==============================] - 1s 420ms/step
#   Batch 25/42, d_real_loss: 0.0683, d_real_acc: 2.1424, d_fake_loss: 0.0625, d_fake_acc: 0.1102, g_loss: 0.1017, g_acc: 0.2348
# 2/2 [==============================] - 1s 427ms/step
#   Batch 26/42, d_real_loss: 0.0298, d_real_acc: 1.9552, d_fake_loss: 0.0517, d_fake_acc: 0.1148, g_loss: 0.0739, g_acc: 0.1567
# 2/2 [==============================] - 1s 411ms/step
#   Batch 27/42, d_real_loss: 0.0230, d_real_acc: 2.2721, d_fake_loss: 0.0314, d_fake_acc: 0.1125, g_loss: 0.1208, g_acc: 0.1266
# 2/2 [==============================] - 1s 413ms/step
#   Batch 28/42, d_real_loss: 0.0270, d_real_acc: 2.1796, d_fake_loss: 0.0560, d_fake_acc: 0.1635, g_loss: 0.0797, g_acc: 0.1543
# 2/2 [==============================] - 1s 426ms/step
#   Batch 29/42, d_real_loss: 0.0632, d_real_acc: 2.1775, d_fake_loss: 0.0608, d_fake_acc: 0.1699, g_loss: 0.0627, g_acc: 0.1843
# 2/2 [==============================] - 1s 424ms/step
#   Batch 30/42, d_real_loss: 0.0338, d_real_acc: 2.2634, d_fake_loss: 0.0336, d_fake_acc: 0.1025, g_loss: 0.0889, g_acc: 0.2205
# 2/2 [==============================] - 1s 431ms/step
#   Batch 31/42, d_real_loss: 0.0414, d_real_acc: 1.7744, d_fake_loss: 0.0208, d_fake_acc: 0.1142, g_loss: 0.0907, g_acc: 0.1001
# 2/2 [==============================] - 1s 416ms/step
#   Batch 32/42, d_real_loss: 0.0486, d_real_acc: 2.2391, d_fake_loss: 0.0349, d_fake_acc: 0.0869, g_loss: 0.1033, g_acc: 0.1214
# 2/2 [==============================] - 1s 422ms/step
#   Batch 33/42, d_real_loss: 0.0465, d_real_acc: 2.0490, d_fake_loss: 0.0468, d_fake_acc: 0.0946, g_loss: 0.0889, g_acc: 0.1561
# 2/2 [==============================] - 1s 704ms/step
#   Batch 34/42, d_real_loss: 0.0466, d_real_acc: 1.9829, d_fake_loss: 0.0564, d_fake_acc: 0.0840, g_loss: 0.0918, g_acc: 0.1425
# 2/2 [==============================] - 1s 437ms/step
#   Batch 35/42, d_real_loss: 0.0536, d_real_acc: 2.1309, d_fake_loss: 0.0599, d_fake_acc: 0.0708, g_loss: 0.0424, g_acc: 0.1198
# 2/2 [==============================] - 1s 410ms/step
#   Batch 36/42, d_real_loss: 0.0576, d_real_acc: 2.2623, d_fake_loss: 0.0495, d_fake_acc: 0.0669, g_loss: 0.0458, g_acc: 0.1267
# 2/2 [==============================] - 1s 683ms/step
#   Batch 37/42, d_real_loss: 0.0320, d_real_acc: 2.0201, d_fake_loss: 0.0102, d_fake_acc: 0.0863, g_loss: 0.0997, g_acc: 0.1867
# 2/2 [==============================] - 1s 410ms/step
#   Batch 38/42, d_real_loss: 0.0621, d_real_acc: 2.2731, d_fake_loss: 0.0423, d_fake_acc: 0.0725, g_loss: 0.0890, g_acc: 0.1328
# 2/2 [==============================] - 1s 413ms/step
#   Batch 39/42, d_real_loss: 0.0471, d_real_acc: 2.1352, d_fake_loss: 0.0249, d_fake_acc: 0.0770, g_loss: 0.1046, g_acc: 0.1072
# 2/2 [==============================] - 1s 740ms/step
#   Batch 40/42, d_real_loss: 0.0264, d_real_acc: 1.9913, d_fake_loss: 0.0378, d_fake_acc: 0.0863, g_loss: 0.0754, g_acc: 0.1392
# 2/2 [==============================] - 1s 414ms/step
#   Batch 41/42, d_real_loss: 0.0555, d_real_acc: 2.0921, d_fake_loss: 0.0416, d_fake_acc: 0.0580, g_loss: 0.0610, g_acc: 0.1075
# 2/2 [==============================] - 1s 420ms/step
#   Batch 42/42, d_real_loss: 0.0141, d_real_acc: 2.1451, d_fake_loss: 0.0152, d_fake_acc: 0.0801, g_loss: 0.0527, g_acc: 0.1294
# Epoch 6/500
# 2/2 [==============================] - 1s 418ms/step
#   Batch 1/42, d_real_loss: 0.0107, d_real_acc: 1.8102, d_fake_loss: 0.0190, d_fake_acc: 0.0496, g_loss: 0.0744, g_acc: 0.0680
# 2/2 [==============================] - 1s 605ms/step
#   Batch 2/42, d_real_loss: 0.0208, d_real_acc: 2.2187, d_fake_loss: 0.0165, d_fake_acc: 0.0717, g_loss: 0.0724, g_acc: 0.0957
# 2/2 [==============================] - 1s 417ms/step
#   Batch 3/42, d_real_loss: 0.0506, d_real_acc: 2.1916, d_fake_loss: 0.0471, d_fake_acc: 0.0510, g_loss: 0.0621, g_acc: 0.1479
# 2/2 [==============================] - 1s 426ms/step
#   Batch 4/42, d_real_loss: 0.0293, d_real_acc: 2.1938, d_fake_loss: 0.0262, d_fake_acc: 0.0654, g_loss: 0.0429, g_acc: 0.1413
# 2/2 [==============================] - 1s 681ms/step
#   Batch 5/42, d_real_loss: 0.0299, d_real_acc: 2.2378, d_fake_loss: 0.0118, d_fake_acc: 0.0596, g_loss: 0.0902, g_acc: 0.1209
# 2/2 [==============================] - 1s 407ms/step
#   Batch 6/42, d_real_loss: 0.0342, d_real_acc: 1.9589, d_fake_loss: 0.0177, d_fake_acc: 0.0585, g_loss: 0.0534, g_acc: 0.1195
# 2/2 [==============================] - 1s 418ms/step
#   Batch 7/42, d_real_loss: 0.0274, d_real_acc: 2.0718, d_fake_loss: 0.0161, d_fake_acc: 0.0407, g_loss: 0.0424, g_acc: 0.0809
# 2/2 [==============================] - 1s 686ms/step
#   Batch 8/42, d_real_loss: 0.0700, d_real_acc: 2.2688, d_fake_loss: 0.0152, d_fake_acc: 0.0514, g_loss: 0.0525, g_acc: 0.0793
# 2/2 [==============================] - 1s 415ms/step
#   Batch 9/42, d_real_loss: 0.0159, d_real_acc: 2.0694, d_fake_loss: 0.0167, d_fake_acc: 0.0536, g_loss: 0.0307, g_acc: 0.1515
# 2/2 [==============================] - 1s 402ms/step
#   Batch 10/42, d_real_loss: 0.0478, d_real_acc: 2.0390, d_fake_loss: 0.0059, d_fake_acc: 0.0571, g_loss: 0.0930, g_acc: 0.0928
# 2/2 [==============================] - 1s 686ms/step
#   Batch 11/42, d_real_loss: 0.0068, d_real_acc: 1.9661, d_fake_loss: 0.0084, d_fake_acc: 0.0488, g_loss: 0.0813, g_acc: 0.0847
# 2/2 [==============================] - 1s 422ms/step
#   Batch 12/42, d_real_loss: 0.0116, d_real_acc: 2.2091, d_fake_loss: 0.0285, d_fake_acc: 0.0548, g_loss: 0.0490, g_acc: 0.1035
# 2/2 [==============================] - 1s 410ms/step
#   Batch 13/42, d_real_loss: 0.0138, d_real_acc: 2.0375, d_fake_loss: 0.0678, d_fake_acc: 0.0581, g_loss: 0.0295, g_acc: 0.1144
# 2/2 [==============================] - 1s 429ms/step
#   Batch 14/42, d_real_loss: 0.0154, d_real_acc: 1.9995, d_fake_loss: 0.0126, d_fake_acc: 0.0432, g_loss: 0.0656, g_acc: 0.1018
# 2/2 [==============================] - 1s 422ms/step
#   Batch 15/42, d_real_loss: 0.0365, d_real_acc: 2.1381, d_fake_loss: 0.0125, d_fake_acc: 0.0519, g_loss: 0.0669, g_acc: 0.1287
# 2/2 [==============================] - 1s 416ms/step
#   Batch 16/42, d_real_loss: 0.0147, d_real_acc: 2.2300, d_fake_loss: 0.0165, d_fake_acc: 0.0366, g_loss: 0.0859, g_acc: 0.0867
# 2/2 [==============================] - 1s 408ms/step
#   Batch 17/42, d_real_loss: 0.0405, d_real_acc: 1.9461, d_fake_loss: 0.0206, d_fake_acc: 0.0352, g_loss: 0.0468, g_acc: 0.0731
# 2/2 [==============================] - 1s 697ms/step
#   Batch 18/42, d_real_loss: 0.0150, d_real_acc: 2.2303, d_fake_loss: 0.0466, d_fake_acc: 0.0473, g_loss: 0.0892, g_acc: 0.1072
# 2/2 [==============================] - 1s 419ms/step
#   Batch 19/42, d_real_loss: 0.0201, d_real_acc: 1.7901, d_fake_loss: 0.0345, d_fake_acc: 0.0376, g_loss: 0.0510, g_acc: 0.1063
# 2/2 [==============================] - 1s 414ms/step
#   Batch 20/42, d_real_loss: 0.0131, d_real_acc: 2.0814, d_fake_loss: 0.0149, d_fake_acc: 0.0465, g_loss: 0.0411, g_acc: 0.1238
# 2/2 [==============================] - 1s 416ms/step
#   Batch 21/42, d_real_loss: 0.0207, d_real_acc: 2.1259, d_fake_loss: 0.0380, d_fake_acc: 0.0393, g_loss: 0.0694, g_acc: 0.0958
# 2/2 [==============================] - 1s 428ms/step
#   Batch 22/42, d_real_loss: 0.0203, d_real_acc: 2.2259, d_fake_loss: 0.0179, d_fake_acc: 0.0587, g_loss: 0.0399, g_acc: 0.1544
# 2/2 [==============================] - 1s 416ms/step
#   Batch 23/42, d_real_loss: 0.0183, d_real_acc: 2.2345, d_fake_loss: 0.0132, d_fake_acc: 0.0445, g_loss: 0.0798, g_acc: 0.0555
# 2/2 [==============================] - 1s 412ms/step
#   Batch 24/42, d_real_loss: 0.0260, d_real_acc: 1.8811, d_fake_loss: 0.0219, d_fake_acc: 0.0517, g_loss: 0.0339, g_acc: 0.0679
# 2/2 [==============================] - 1s 483ms/step
#   Batch 25/42, d_real_loss: 0.0237, d_real_acc: 1.9133, d_fake_loss: 0.0425, d_fake_acc: 0.0599, g_loss: 0.0974, g_acc: 0.1339
# 2/2 [==============================] - 1s 423ms/step
#   Batch 26/42, d_real_loss: 0.0176, d_real_acc: 1.9845, d_fake_loss: 0.0552, d_fake_acc: 0.0463, g_loss: 0.0162, g_acc: 0.0966
# 2/2 [==============================] - 1s 435ms/step
#   Batch 27/42, d_real_loss: 0.0236, d_real_acc: 2.1043, d_fake_loss: 0.0214, d_fake_acc: 0.0310, g_loss: 0.0599, g_acc: 0.0665
# 2/2 [==============================] - 1s 696ms/step
#   Batch 28/42, d_real_loss: 0.0298, d_real_acc: 1.8415, d_fake_loss: 0.0361, d_fake_acc: 0.0381, g_loss: 0.0425, g_acc: 0.1253
# 2/2 [==============================] - 1s 430ms/step
#   Batch 29/42, d_real_loss: 0.0270, d_real_acc: 1.9260, d_fake_loss: 0.0176, d_fake_acc: 0.0321, g_loss: 0.0777, g_acc: 0.0785
# 2/2 [==============================] - 1s 412ms/step
#   Batch 30/42, d_real_loss: 0.0282, d_real_acc: 2.0778, d_fake_loss: 0.0291, d_fake_acc: 0.0674, g_loss: 0.0780, g_acc: 0.1066
# 2/2 [==============================] - 1s 417ms/step
#   Batch 31/42, d_real_loss: 0.0361, d_real_acc: 2.0773, d_fake_loss: 0.0523, d_fake_acc: 0.0261, g_loss: 0.0285, g_acc: 0.1199
# 2/2 [==============================] - 1s 430ms/step
#   Batch 32/42, d_real_loss: 0.0206, d_real_acc: 2.0942, d_fake_loss: 0.0382, d_fake_acc: 0.0614, g_loss: 0.0473, g_acc: 0.0738
# 2/2 [==============================] - 1s 411ms/step
#   Batch 33/42, d_real_loss: 0.0486, d_real_acc: 2.1470, d_fake_loss: 0.0154, d_fake_acc: 0.0249, g_loss: 0.0723, g_acc: 0.0821
# 2/2 [==============================] - 1s 436ms/step
#   Batch 34/42, d_real_loss: 0.0316, d_real_acc: 1.8634, d_fake_loss: 0.0128, d_fake_acc: 0.0263, g_loss: 0.0657, g_acc: 0.0782
# 2/2 [==============================] - 1s 634ms/step
#   Batch 35/42, d_real_loss: 0.0166, d_real_acc: 2.1110, d_fake_loss: 0.0514, d_fake_acc: 0.0379, g_loss: 0.0431, g_acc: 0.1135
# 2/2 [==============================] - 1s 411ms/step
#   Batch 36/42, d_real_loss: 0.0604, d_real_acc: 1.8845, d_fake_loss: 0.0237, d_fake_acc: 0.0399, g_loss: 0.0539, g_acc: 0.1000
# 2/2 [==============================] - 1s 426ms/step
#   Batch 37/42, d_real_loss: 0.0549, d_real_acc: 2.3196, d_fake_loss: 0.0215, d_fake_acc: 0.0344, g_loss: 0.0355, g_acc: 0.0909
# 2/2 [==============================] - 1s 711ms/step
#   Batch 38/42, d_real_loss: 0.0271, d_real_acc: 2.0746, d_fake_loss: 0.0300, d_fake_acc: 0.0503, g_loss: 0.0750, g_acc: 0.0884
# 2/2 [==============================] - 1s 413ms/step
#   Batch 39/42, d_real_loss: 0.0359, d_real_acc: 1.9444, d_fake_loss: 0.0343, d_fake_acc: 0.0304, g_loss: 0.0267, g_acc: 0.0658
# 2/2 [==============================] - 1s 433ms/step
#   Batch 40/42, d_real_loss: 0.0146, d_real_acc: 1.7138, d_fake_loss: 0.0532, d_fake_acc: 0.0240, g_loss: 0.0463, g_acc: 0.1075
# 2/2 [==============================] - 1s 676ms/step
#   Batch 41/42, d_real_loss: 0.0244, d_real_acc: 2.1362, d_fake_loss: 0.0360, d_fake_acc: 0.0706, g_loss: 0.0514, g_acc: 0.1046
# 2/2 [==============================] - 1s 415ms/step
#   Batch 42/42, d_real_loss: 0.0719, d_real_acc: 1.9115, d_fake_loss: 0.0307, d_fake_acc: 0.0393, g_loss: 0.0333, g_acc: 0.1192
# Epoch 7/500
# 2/2 [==============================] - 1s 423ms/step
#   Batch 1/42, d_real_loss: 0.0171, d_real_acc: 1.8451, d_fake_loss: 0.0093, d_fake_acc: 0.0299, g_loss: 0.0627, g_acc: 0.0642
# 2/2 [==============================] - 1s 432ms/step
#   Batch 2/42, d_real_loss: 0.0102, d_real_acc: 2.0889, d_fake_loss: 0.0122, d_fake_acc: 0.0566, g_loss: 0.0779, g_acc: 0.1115
# 2/2 [==============================] - 1s 401ms/step
#   Batch 3/42, d_real_loss: 0.0351, d_real_acc: 1.9001, d_fake_loss: 0.0241, d_fake_acc: 0.0348, g_loss: 0.0696, g_acc: 0.1132
# 2/2 [==============================] - 1s 415ms/step
#   Batch 4/42, d_real_loss: 0.0290, d_real_acc: 2.1746, d_fake_loss: 0.0865, d_fake_acc: 0.0349, g_loss: 0.0115, g_acc: 0.0709
# 2/2 [==============================] - 1s 408ms/step
#   Batch 5/42, d_real_loss: 0.0539, d_real_acc: 1.9650, d_fake_loss: 0.0201, d_fake_acc: 0.0415, g_loss: 0.0376, g_acc: 0.0593
# 2/2 [==============================] - 1s 440ms/step
#   Batch 6/42, d_real_loss: 0.0307, d_real_acc: 1.8470, d_fake_loss: 0.0187, d_fake_acc: 0.0329, g_loss: 0.0378, g_acc: 0.0783
# 2/2 [==============================] - 1s 415ms/step
#   Batch 7/42, d_real_loss: 0.0220, d_real_acc: 2.2515, d_fake_loss: 0.0205, d_fake_acc: 0.0276, g_loss: 0.0652, g_acc: 0.0964
# 2/2 [==============================] - 1s 428ms/step
#   Batch 8/42, d_real_loss: 0.0522, d_real_acc: 2.0755, d_fake_loss: 0.0176, d_fake_acc: 0.0286, g_loss: 0.0396, g_acc: 0.0723
# 2/2 [==============================] - 1s 688ms/step
#   Batch 9/42, d_real_loss: 0.0169, d_real_acc: 1.6857, d_fake_loss: 0.0627, d_fake_acc: 0.0182, g_loss: 0.0269, g_acc: 0.1091
# 2/2 [==============================] - 1s 434ms/step
#   Batch 10/42, d_real_loss: 0.0269, d_real_acc: 1.8065, d_fake_loss: 0.0162, d_fake_acc: 0.0290, g_loss: 0.0805, g_acc: 0.0516
# 2/2 [==============================] - 1s 412ms/step
#   Batch 11/42, d_real_loss: 0.0333, d_real_acc: 1.9033, d_fake_loss: 0.0415, d_fake_acc: 0.0334, g_loss: 0.0222, g_acc: 0.0877
# 2/2 [==============================] - 2s 775ms/step
#   Batch 12/42, d_real_loss: 0.0463, d_real_acc: 2.0985, d_fake_loss: 0.0262, d_fake_acc: 0.0285, g_loss: 0.0238, g_acc: 0.0637
# 2/2 [==============================] - 1s 427ms/step
#   Batch 13/42, d_real_loss: 0.0304, d_real_acc: 2.2182, d_fake_loss: 0.0245, d_fake_acc: 0.0249, g_loss: 0.0459, g_acc: 0.0874
# 2/2 [==============================] - 1s 410ms/step
#   Batch 14/42, d_real_loss: 0.0325, d_real_acc: 2.4043, d_fake_loss: 0.0106, d_fake_acc: 0.0324, g_loss: 0.0228, g_acc: 0.0580
# 2/2 [==============================] - 1s 433ms/step
# ...
# 2/2 [==============================] - 1s 627ms/step
#   Batch 15/42, d_real_loss: 0.8145, d_real_acc: 1.2044, d_fake_loss: 0.7161, d_fake_acc: 0.1041, g_loss: 0.8999, g_acc: 0.0764
# 2/2 [==============================] - 1s 416ms/step
#   Batch 16/42, d_real_loss: 0.8197, d_real_acc: 0.8944, d_fake_loss: 0.6883, d_fake_acc: 0.0686, g_loss: 0.8712, g_acc: 0.0621
# 2/2 [==============================] - 1s 425ms/step
#   Batch 17/42, d_real_loss: 0.7711, d_real_acc: 1.0988, d_fake_loss: 0.8781, d_fake_acc: 0.1413, g_loss: 1.0552, g_acc: 0.1015
# 2/2 [==============================] - 1s 439ms/step
#   Batch 18/42, d_real_loss: 0.9215, d_real_acc: 1.1386, d_fake_loss: 0.7728, d_fake_acc: 0.0422, g_loss: 1.0066, g_acc: 0.0981
# 2/2 [==============================] - 1s 751ms/step
#   Batch 19/42, d_real_loss: 0.7372, d_real_acc: 1.1515, d_fake_loss: 0.8634, d_fake_acc: 0.1223, g_loss: 0.9798, g_acc: 0.0641
# 2/2 [==============================] - 1s 408ms/step
#   Batch 20/42, d_real_loss: 0.7331, d_real_acc: 1.1651, d_fake_loss: 0.7481, d_fake_acc: 0.1108, g_loss: 1.0721, g_acc: 0.0982
# 2/2 [==============================] - 1s 429ms/step
#   Batch 21/42, d_real_loss: 0.8794, d_real_acc: 1.0220, d_fake_loss: 0.7238, d_fake_acc: 0.1518, g_loss: 0.8821, g_acc: 0.0909
# 2/2 [==============================] - 1s 415ms/step
#   Batch 22/42, d_real_loss: 0.8397, d_real_acc: 1.3868, d_fake_loss: 0.6677, d_fake_acc: 0.0719, g_loss: 0.8373, g_acc: 0.0718
# 2/2 [==============================] - 1s 432ms/step
#   Batch 23/42, d_real_loss: 0.6473, d_real_acc: 1.2172, d_fake_loss: 0.6913, d_fake_acc: 0.0862, g_loss: 0.9218, g_acc: 0.0804
# 2/2 [==============================] - 1s 443ms/step
#   Batch 24/42, d_real_loss: 0.7533, d_real_acc: 0.9670, d_fake_loss: 0.8202, d_fake_acc: 0.1253, g_loss: 0.7985, g_acc: 0.0788
# 2/2 [==============================] - 1s 422ms/step
#   Batch 25/42, d_real_loss: 0.8231, d_real_acc: 1.0885, d_fake_loss: 0.8496, d_fake_acc: 0.1232, g_loss: 0.7274, g_acc: 0.1068
# 2/2 [==============================] - 1s 737ms/step
#   Batch 26/42, d_real_loss: 0.7558, d_real_acc: 1.5138, d_fake_loss: 0.8794, d_fake_acc: 0.0892, g_loss: 0.8253, g_acc: 0.1391
# 2/2 [==============================] - 1s 414ms/step
#   Batch 27/42, d_real_loss: 0.7796, d_real_acc: 0.9340, d_fake_loss: 0.7752, d_fake_acc: 0.0737, g_loss: 0.9692, g_acc: 0.0940
# 2/2 [==============================] - 1s 408ms/step
#   Batch 28/42, d_real_loss: 0.7796, d_real_acc: 1.3234, d_fake_loss: 0.7638, d_fake_acc: 0.0381, g_loss: 1.0074, g_acc: 0.0632
# 2/2 [==============================] - 1s 719ms/step
#   Batch 29/42, d_real_loss: 0.8783, d_real_acc: 1.2142, d_fake_loss: 0.8325, d_fake_acc: 0.0615, g_loss: 0.9994, g_acc: 0.1799
# 2/2 [==============================] - 1s 410ms/step
#   Batch 30/42, d_real_loss: 0.7538, d_real_acc: 1.0130, d_fake_loss: 0.7654, d_fake_acc: 0.1079, g_loss: 1.0080, g_acc: 0.0696
# 2/2 [==============================] - 1s 427ms/step
#   Batch 31/42, d_real_loss: 0.7662, d_real_acc: 1.1475, d_fake_loss: 0.8277, d_fake_acc: 0.0668, g_loss: 0.9137, g_acc: 0.0878
# 2/2 [==============================] - 1s 438ms/step
#   Batch 32/42, d_real_loss: 0.7283, d_real_acc: 0.9848, d_fake_loss: 0.8798, d_fake_acc: 0.1038, g_loss: 0.8468, g_acc: 0.0695
# 2/2 [==============================] - 1s 426ms/step
#   Batch 33/42, d_real_loss: 0.8312, d_real_acc: 0.9400, d_fake_loss: 0.7862, d_fake_acc: 0.0667, g_loss: 0.8511, g_acc: 0.1244
# 2/2 [==============================] - 1s 414ms/step
#   Batch 34/42, d_real_loss: 0.6661, d_real_acc: 1.2097, d_fake_loss: 0.8461, d_fake_acc: 0.0423, g_loss: 0.8249, g_acc: 0.0771
# 2/2 [==============================] - 1s 416ms/step
#   Batch 35/42, d_real_loss: 0.5369, d_real_acc: 1.1978, d_fake_loss: 0.8044, d_fake_acc: 0.0768, g_loss: 0.9213, g_acc: 0.0840
# 2/2 [==============================] - 1s 738ms/step
#   Batch 36/42, d_real_loss: 0.8524, d_real_acc: 0.9379, d_fake_loss: 0.7484, d_fake_acc: 0.0492, g_loss: 1.0085, g_acc: 0.1039
# 2/2 [==============================] - 1s 425ms/step
#   Batch 37/42, d_real_loss: 0.7885, d_real_acc: 1.0176, d_fake_loss: 0.8197, d_fake_acc: 0.0625, g_loss: 0.8922, g_acc: 0.0632
# 2/2 [==============================] - 1s 411ms/step
#   Batch 38/42, d_real_loss: 0.8037, d_real_acc: 1.1921, d_fake_loss: 0.8677, d_fake_acc: 0.0550, g_loss: 0.9814, g_acc: 0.0599
# 2/2 [==============================] - 1s 705ms/step
#   Batch 39/42, d_real_loss: 0.5999, d_real_acc: 0.9599, d_fake_loss: 0.8983, d_fake_acc: 0.0920, g_loss: 0.8950, g_acc: 0.1076
# 2/2 [==============================] - 1s 410ms/step
#   Batch 40/42, d_real_loss: 0.8118, d_real_acc: 1.1379, d_fake_loss: 0.7917, d_fake_acc: 0.0680, g_loss: 0.7829, g_acc: 0.0767
# 2/2 [==============================] - 1s 444ms/step
#   Batch 41/42, d_real_loss: 0.8304, d_real_acc: 1.0962, d_fake_loss: 0.7692, d_fake_acc: 0.0877, g_loss: 0.8192, g_acc: 0.1129
# 2/2 [==============================] - 1s 467ms/step
#   Batch 42/42, d_real_loss: 0.7367, d_real_acc: 1.3185, d_fake_loss: 0.6837, d_fake_acc: 0.1010, g_loss: 0.9514, g_acc: 0.0900
# Epoch 29/500
# 2/2 [==============================] - 1s 420ms/step
#   Batch 1/42, d_real_loss: 0.6765, d_real_acc: 1.2067, d_fake_loss: 0.8177, d_fake_acc: 0.1250, g_loss: 0.8441, g_acc: 0.0954
# 2/2 [==============================] - 1s 426ms/step
#   Batch 2/42, d_real_loss: 0.7829, d_real_acc: 1.3652, d_fake_loss: 0.8151, d_fake_acc: 0.1023, g_loss: 0.9255, g_acc: 0.0878
# 2/2 [==============================] - 1s 427ms/step
#   Batch 3/42, d_real_loss: 0.6997, d_real_acc: 1.1009, d_fake_loss: 0.8487, d_fake_acc: 0.0751, g_loss: 0.9651, g_acc: 0.0651
# 2/2 [==============================] - 1s 738ms/step
#   Batch 4/42, d_real_loss: 0.7247, d_real_acc: 1.3036, d_fake_loss: 0.7785, d_fake_acc: 0.0550, g_loss: 0.9412, g_acc: 0.0947
# 2/2 [==============================] - 1s 634ms/step
#   Batch 5/42, d_real_loss: 0.6965, d_real_acc: 1.0055, d_fake_loss: 0.8432, d_fake_acc: 0.0712, g_loss: 0.8539, g_acc: 0.0870
# 2/2 [==============================] - 1s 436ms/step
#   Batch 6/42, d_real_loss: 0.8445, d_real_acc: 1.1998, d_fake_loss: 0.8014, d_fake_acc: 0.0515, g_loss: 0.9754, g_acc: 0.0763
# 2/2 [==============================] - 1s 455ms/step
#   Batch 7/42, d_real_loss: 0.7606, d_real_acc: 1.3853, d_fake_loss: 0.8242, d_fake_acc: 0.0998, g_loss: 1.1121, g_acc: 0.1226
# 2/2 [==============================] - 1s 413ms/step
#   Batch 8/42, d_real_loss: 0.6817, d_real_acc: 0.9261, d_fake_loss: 0.7493, d_fake_acc: 0.0995, g_loss: 0.8683, g_acc: 0.0814
# 2/2 [==============================] - 1s 415ms/step
#   Batch 9/42, d_real_loss: 0.8238, d_real_acc: 1.1970, d_fake_loss: 0.7040, d_fake_acc: 0.1071, g_loss: 0.8757, g_acc: 0.0803
# 2/2 [==============================] - 1s 691ms/step
#   Batch 10/42, d_real_loss: 0.8699, d_real_acc: 0.8199, d_fake_loss: 0.8264, d_fake_acc: 0.0742, g_loss: 0.8824, g_acc: 0.0780
# 2/2 [==============================] - 1s 433ms/step
#   Batch 11/42, d_real_loss: 0.8159, d_real_acc: 0.9838, d_fake_loss: 0.7226, d_fake_acc: 0.0989, g_loss: 1.1137, g_acc: 0.0995
# 2/2 [==============================] - 1s 418ms/step
#   Batch 12/42, d_real_loss: 0.7634, d_real_acc: 1.0930, d_fake_loss: 0.8149, d_fake_acc: 0.1595, g_loss: 0.9091, g_acc: 0.0851
# 2/2 [==============================] - 1s 512ms/step
#   Batch 13/42, d_real_loss: 0.7698, d_real_acc: 1.1379, d_fake_loss: 0.7233, d_fake_acc: 0.0688, g_loss: 0.9613, g_acc: 0.1646
# 2/2 [==============================] - 1s 417ms/step
#   Batch 14/42, d_real_loss: 0.8100, d_real_acc: 1.0408, d_fake_loss: 0.8933, d_fake_acc: 0.0772, g_loss: 0.8819, g_acc: 0.1012
# 2/2 [==============================] - 1s 423ms/step
#   Batch 15/42, d_real_loss: 0.8389, d_real_acc: 0.8889, d_fake_loss: 0.8591, d_fake_acc: 0.0576, g_loss: 0.7343, g_acc: 0.0601
# 2/2 [==============================] - 1s 432ms/step
#   Batch 16/42, d_real_loss: 0.6200, d_real_acc: 1.1730, d_fake_loss: 0.7708, d_fake_acc: 0.1480, g_loss: 0.8469, g_acc: 0.0713
# 2/2 [==============================] - 1s 693ms/step
#   Batch 17/42, d_real_loss: 0.7217, d_real_acc: 1.0842, d_fake_loss: 0.7522, d_fake_acc: 0.0757, g_loss: 0.9022, g_acc: 0.1193
# 2/2 [==============================] - 1s 451ms/step
#   Batch 18/42, d_real_loss: 0.7875, d_real_acc: 1.2745, d_fake_loss: 0.8817, d_fake_acc: 0.1581, g_loss: 1.0946, g_acc: 0.1110
# 2/2 [==============================] - 1s 419ms/step
#   Batch 19/42, d_real_loss: 0.7375, d_real_acc: 0.9130, d_fake_loss: 0.7316, d_fake_acc: 0.0531, g_loss: 0.8237, g_acc: 0.0693
# 2/2 [==============================] - 1s 684ms/step
#   Batch 20/42, d_real_loss: 0.8165, d_real_acc: 0.8902, d_fake_loss: 0.9172, d_fake_acc: 0.1111, g_loss: 0.9837, g_acc: 0.1011
# 2/2 [==============================] - 1s 442ms/step
#   Batch 21/42, d_real_loss: 0.6935, d_real_acc: 1.1467, d_fake_loss: 0.7396, d_fake_acc: 0.0892, g_loss: 1.0573, g_acc: 0.0888
# 2/2 [==============================] - 1s 432ms/step
#   Batch 22/42, d_real_loss: 0.7405, d_real_acc: 1.1265, d_fake_loss: 0.7131, d_fake_acc: 0.0635, g_loss: 0.8293, g_acc: 0.0924
# 2/2 [==============================] - 1s 581ms/step
#   Batch 23/42, d_real_loss: 0.8560, d_real_acc: 1.0827, d_fake_loss: 0.7560, d_fake_acc: 0.0822, g_loss: 1.0978, g_acc: 0.0442
# 2/2 [==============================] - 1s 435ms/step
#   Batch 24/42, d_real_loss: 0.7150, d_real_acc: 1.0768, d_fake_loss: 0.8538, d_fake_acc: 0.0925, g_loss: 0.8557, g_acc: 0.0785
# 2/2 [==============================] - 1s 423ms/step
#   Batch 25/42, d_real_loss: 0.9118, d_real_acc: 1.3800, d_fake_loss: 0.8073, d_fake_acc: 0.1070, g_loss: 0.9283, g_acc: 0.0713
# 2/2 [==============================] - 1s 449ms/step
#   Batch 26/42, d_real_loss: 0.6800, d_real_acc: 1.0453, d_fake_loss: 0.7742, d_fake_acc: 0.0599, g_loss: 0.9918, g_acc: 0.0731
# 2/2 [==============================] - 1s 750ms/step
#   Batch 27/42, d_real_loss: 0.9017, d_real_acc: 0.9522, d_fake_loss: 0.7899, d_fake_acc: 0.1090, g_loss: 0.8894, g_acc: 0.0886
# 2/2 [==============================] - 1s 441ms/step
#   Batch 28/42, d_real_loss: 0.8718, d_real_acc: 1.0216, d_fake_loss: 0.8149, d_fake_acc: 0.0622, g_loss: 0.9968, g_acc: 0.1272
# 2/2 [==============================] - 1s 430ms/step
#   Batch 29/42, d_real_loss: 0.8927, d_real_acc: 1.1865, d_fake_loss: 0.7661, d_fake_acc: 0.0744, g_loss: 0.8750, g_acc: 0.0600
# 2/2 [==============================] - 1s 674ms/step
#   Batch 30/42, d_real_loss: 0.7645, d_real_acc: 1.1805, d_fake_loss: 0.8760, d_fake_acc: 0.0791, g_loss: 0.8814, g_acc: 0.0792
# 2/2 [==============================] - 1s 434ms/step
#   Batch 31/42, d_real_loss: 0.7131, d_real_acc: 1.2510, d_fake_loss: 0.7992, d_fake_acc: 0.0931, g_loss: 1.0444, g_acc: 0.0586
# 2/2 [==============================] - 1s 425ms/step
#   Batch 32/42, d_real_loss: 0.7496, d_real_acc: 1.1851, d_fake_loss: 0.7570, d_fake_acc: 0.0968, g_loss: 0.9041, g_acc: 0.1543
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-bc22e93c0de1> in <cell line: 13>()
#      11     # Save GAN model (including both generator and discriminator)
#      12     save_model(gan_model, 'acgan_model.h5')  # Save CGAN model
# ---> 13 run_cgan()
#
# <ipython-input-9-bc22e93c0de1> in run_cgan()
#       5     g_model = define_generator(latent_dim=100)
#       6     gan_model = define_gan(g_model, d_model)
# ----> 7     train(g_model, d_model, gan_model, (X_train, y_train), latent_dim=100, n_epochs=500, n_batch=64)
#       8     save_model(d_model, 'discriminator_model.h5')  # Save discriminator model
#       9     # Save generator model
#
# <ipython-input-8-f64cfbac073e> in train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs, n_batch)
#       9             X_real, labels_real = X_train[ix], y_train[ix]
#      10             y_real = np.ones((n_batch, 1))
# ---> 11             _, d_r1, d_r2 = d_model.train_on_batch(X_real, [y_real, labels_real])
#      12
#      13             X_fake, labels_fake = generate_fake_samples(g_model, latent_dim, n_batch)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    2785             )
#    2786             self.train_function = self.make_train_function()
# -> 2787             logs = self.train_function(iterator)
#    2788
#    2789         logs = tf_utils.sync_to_numpy_or_python_type(logs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     866       # In this case we have created variables on the first call, so we run the
#     867       # defunned version which is guaranteed to never create variables.
# --> 868       return tracing_compilation.call_function(
#     869           args, kwds, self._no_variable_creation_config
#     870       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
