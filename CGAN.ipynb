# %% [markdown]
# 0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Importing Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.optimizers import Adam
from keras.models import Model
from keras.layers import Input, Dense, Reshape, Flatten, Conv2D, Conv2DTranspose, LeakyReLU, Dropout, Embedding, Concatenate
from matplotlib import pyplot as plt
from keras.layers import Conv2D, Conv2DTranspose, LeakyReLU, BatchNormalization
from keras.models import save_model
from math import sqrt
from numpy import asarray
from numpy.random import randn
from keras.models import load_model

# %% [markdown]
# ##Loading and Preprocessing the dataset

# %%
def load_fer2013_dataset():
    # Load the FER2013 dataset CSV file
    data = pd.read_csv('/content/fer_chnge.csv')

    # Extract pixel and emotion labels
    pixels = data['pixels'].values
    emotions = data['emotion'].values

    X = []
    y = []
    for pixel_sequence, emotion in zip(pixels, emotions):
        # Parse the pixel sequence string into a list of integers
        pixel_values = [int(pixel) for pixel in pixel_sequence.split()]

        # Ensure that the pixel values array matches the expected size (48x48 = 2304 pixels)
        if len(pixel_values) != 2304:
            continue  # Skip sequences that are not 48x48

        # Reshape the pixel values into a 48x48 grayscale image (1 channel)
        image_array = np.array(pixel_values, dtype=np.uint8).reshape(48, 48, 1)

        # Normalize pixel values to range [0, 1]
        image_array = image_array.astype('float32') / 255.0

        # Append the processed image array and corresponding emotion label to the lists
        X.append(image_array)
        y.append(emotion)

    # Convert the lists to numpy arrays
    X = np.array(X)
    y = np.array(y, dtype='int32')

    return (X, y)

# %% [markdown]
# ##Discriminator Model

# %%
def define_discriminator(in_shape=(48, 48, 1), n_classes=7):
    # Label input
    in_label = Input(shape=(1,))
    # Embedding for categorical input
    li = Embedding(n_classes, 50)(in_label)
    # Scale up to image dimensions with linear activation
    n_nodes = in_shape[0] * in_shape[1]
    li = Dense(n_nodes)(li)
    # Reshape to additional channel
    li = Reshape((in_shape[0], in_shape[1], 1))(li)
    # Image input
    in_image = Input(shape=in_shape)
    # Concatenate label as a channel
    merge = Concatenate()([in_image, li])
    # Downsample
    fe = Conv2D(128, (3,3), strides=(2,2), padding='same')(merge)
    fe = LeakyReLU(alpha=0.2)(fe)
    # Downsample
    fe = Conv2D(128, (3,3), strides=(2,2), padding='same')(fe)
    fe = LeakyReLU(alpha=0.2)(fe)
    # Flatten feature maps
    fe = Flatten()(fe)
    # Dropout
    fe = Dropout(0.4)(fe)
    # Output
    out_layer = Dense(1, activation='sigmoid')(fe)
    # Define model
    model = Model([in_image, in_label], out_layer)
    # Compile model
    opt = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
    return model
d=define_discriminator()
d.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 1)]                  0         []
#
#  embedding_4 (Embedding)     (None, 1, 50)                350       ['input_9[0][0]']
#
#  dense_8 (Dense)             (None, 1, 2304)              117504    ['embedding_4[0][0]']
#
#  input_10 (InputLayer)       [(None, 48, 48, 1)]          0         []
#
#  reshape_6 (Reshape)         (None, 48, 48, 1)            0         ['dense_8[0][0]']
#
#  concatenate_4 (Concatenate  (None, 48, 48, 2)            0         ['input_10[0][0]',
#  )                                                                   'reshape_6[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 24, 24, 128)          2432      ['concatenate_4[0][0]']
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 24, 24, 128)          0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 128)          147584    ['leaky_re_lu_12[0][0]']
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 12, 12, 128)          0         ['conv2d_7[0][0]']
#
#  flatten_2 (Flatten)         (None, 18432)                0         ['leaky_re_lu_13[0][0]']
#
#  dropout_2 (Dropout)         (None, 18432)                0         ['flatten_2[0][0]']
#
#  dense_9 (Dense)             (None, 1)                    18433     ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 286303 (1.09 MB)
# Trainable params: 286303 (1.09 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ##Generator Model

# %%
def define_generator(latent_dim=100, n_classes=7):
    # Label input
    in_label = Input(shape=(1,))
    # Embedding for categorical input
    li = Embedding(n_classes, 50)(in_label)
    # Linear multiplication
    n_nodes = 12 * 12 * 128  # Calculate the correct number of nodes
    li = Dense(n_nodes)(li)
    li = LeakyReLU(alpha=0.2)(li)
    # Reshape to 12x12 feature maps
    li = Reshape((12, 12, 128))(li)
    # Image generator input
    in_lat = Input(shape=(latent_dim,))
    # Foundation for 12x12 image
    n_nodes = 128 * 12 * 12
    gen = Dense(n_nodes)(in_lat)
    gen = LeakyReLU(alpha=0.2)(gen)
    gen = Reshape((12, 12, 128))(gen)
    # Merge image generator and label input
    merge = Concatenate()([gen, li])
    # Upsample to 24x24
    gen = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same')(merge)
    gen = LeakyReLU(alpha=0.2)(gen)
    # Upsample to 48x48
    gen = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same')(gen)
    gen = LeakyReLU(alpha=0.2)(gen)
    # Output
    out_layer = Conv2D(1, (12, 12), activation='tanh', padding='same')(gen)
    # Define model
    model = Model([in_lat, in_label], out_layer)
    return model
g=define_generator()
g.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, 1)]                  0         []
#
#  input_12 (InputLayer)       [(None, 100)]                0         []
#
#  embedding_5 (Embedding)     (None, 1, 50)                350       ['input_11[0][0]']
#
#  dense_11 (Dense)            (None, 18432)                1861632   ['input_12[0][0]']
#
#  dense_10 (Dense)            (None, 1, 18432)             940032    ['embedding_5[0][0]']
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 18432)                0         ['dense_11[0][0]']
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 1, 18432)             0         ['dense_10[0][0]']
#
#  reshape_8 (Reshape)         (None, 12, 12, 128)          0         ['leaky_re_lu_15[0][0]']
#
#  reshape_7 (Reshape)         (None, 12, 12, 128)          0         ['leaky_re_lu_14[0][0]']
#
#  concatenate_5 (Concatenate  (None, 12, 12, 256)          0         ['reshape_8[0][0]',
#  )                                                                   'reshape_7[0][0]']
#
#  conv2d_transpose_4 (Conv2D  (None, 24, 24, 128)          524416    ['concatenate_5[0][0]']
#  Transpose)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 24, 24, 128)          0         ['conv2d_transpose_4[0][0]']
#
#  conv2d_transpose_5 (Conv2D  (None, 48, 48, 128)          262272    ['leaky_re_lu_16[0][0]']
#  Transpose)
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 48, 48, 128)          0         ['conv2d_transpose_5[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 48, 48, 1)            18433     ['leaky_re_lu_17[0][0]']
#
# ==================================================================================================
# Total params: 3607135 (13.76 MB)
# Trainable params: 3607135 (13.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ##GAN Model(D+G)

# %%
def define_gan(g_model, d_model):
    # Make weights in the discriminator not trainable
    d_model.trainable = False
    # Get noise and label inputs from generator model
    gen_noise, gen_label = g_model.input
    # Get image output from the generator model
    gen_output = g_model.output
    # Connect image output and label input from generator as inputs to discriminator
    gan_output = d_model([gen_output, gen_label])
    # Define GAN model as taking noise and label and outputting a classification
    model = Model([gen_noise, gen_label], gan_output)
    # Compile model
    opt = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt)
    return model

# %%
def generate_fake_samples(generator, latent_dim, n_samples, n_classes=7):
    # Generate points in latent space
    z_input = np.random.randn(latent_dim * n_samples)
    z_input = z_input.reshape(n_samples, latent_dim)
    # Generate random class labels
    labels = np.random.randint(0, n_classes, n_samples).reshape(-1, 1)
    # Generate images
    X_fake = generator.predict([z_input, labels])
    return X_fake, labels

# %% [markdown]
# ##Train the GAN

# %%
import os
save_dir = '/content/drive/MyDrive/cgan2'
os.makedirs(save_dir, exist_ok=True)

def train_gan(g_model, d_model, gan_model, dataset, latent_dim, n_epochs, n_batch):
    # Unpack dataset
    X_train, y_train = dataset
    bat_per_epo = 42
    for epoch in range(1, n_epochs + 1):
        print(f"Epoch {epoch}/{n_epochs}")
        for batch in range(bat_per_epo):
            # Get real samples
            ix = np.random.randint(0, X_train.shape[0], n_batch)
            X_real, labels_real = X_train[ix], y_train[ix]
            y_real = np.ones((n_batch, 1))
            # Update discriminator on real samples
            d_loss_real,_= d_model.train_on_batch([X_real, labels_real], y_real)
            # Generate fake samples
            X_fake, labels_fake = generate_fake_samples(g_model, latent_dim, n_batch)
            y_fake = np.zeros((n_batch, 1))
            # Update discriminator on fake samples
            d_loss_fake,_= d_model.train_on_batch([X_fake, labels_fake], y_fake)
            # Prepare points in latent space as input for the generator
            z_input = np.random.randn(n_batch * latent_dim)
            z_input = z_input.reshape(n_batch, latent_dim)
            labels_gan = np.random.randint(0, 7, n_batch).reshape(-1, 1)
            y_gan = np.ones((n_batch, 1))
            # Update the generator via the discriminator's error
            g_loss= gan_model.train_on_batch([z_input, labels_gan], y_gan)

            print(f"  Batch {batch + 1}/{bat_per_epo}, d_real_loss: {d_loss_real:.4f}, "
                  f"d_fake_loss: {d_loss_fake:.4f},g_loss: {g_loss:.4f}")

        # Save generated images every few epochs
        if epoch % 100 == 0:
          examples=10
          latent_dim=100
          generator=g_model
          latent_points = np.random.randn(examples * latent_dim)
          latent_points = latent_points.reshape(examples, latent_dim)
          labels = np.random.randint(0, 7, examples).reshape(-1, 1)
          X_fake = generator.predict([latent_points, labels])
          plt.figure(figsize=(10, 10))
          for i in range(examples):
            plt.subplot(1, examples, i + 1)
            plt.imshow(X_fake[i].reshape(48, 48), cmap='gray')
            plt.title('Label: %d' % labels[i])
            plt.axis('off')
          filename = save_dir + '/generated_plot_epoch_%04d.png' % (epoch)
          plt.savefig(filename)
          plt.close()

# %% [markdown]
# ##Run the GAN

# %%
def run_cgan():
    # Load FER2013 dataset
    dataset = load_fer2013_dataset()
    X_train, y_train = dataset
    # Create discriminator and generator models
    d_model = define_discriminator()
    g_model = define_generator(latent_dim=100)
    # Create GAN model
    gan_model = define_gan(g_model, d_model)
    # Train the GAN
    train_gan(g_model, d_model, gan_model, (X_train, y_train), latent_dim=100, n_epochs=10000, n_batch=128)
    # Save discriminator model
    save_model(d_model, 'discriminator_model.h5')  # Save discriminator model
    # Save generator model
    save_model(g_model, 'generator_model.h5')  # Save generator model
    # Save GAN model (including both generator and discriminator)
    save_model(gan_model, 'cgan_model.h5')  # Save CGAN model
run_cgan()
# Out:
# Streaming output truncated to the last 5000 lines.
#   Batch 8/42, d_real_loss: 0.6407, d_fake_loss: 0.6709,g_loss: 0.9362
# 4/4 [==============================] - 0s 11ms/step
#   Batch 9/42, d_real_loss: 0.6685, d_fake_loss: 0.6605,g_loss: 0.8320
# 4/4 [==============================] - 0s 9ms/step
#   Batch 10/42, d_real_loss: 0.6694, d_fake_loss: 0.6495,g_loss: 1.0363
# 4/4 [==============================] - 0s 9ms/step
#   Batch 11/42, d_real_loss: 0.6399, d_fake_loss: 0.6688,g_loss: 0.9771
# 4/4 [==============================] - 0s 8ms/step
#   Batch 12/42, d_real_loss: 0.6311, d_fake_loss: 0.6539,g_loss: 0.9507
# 4/4 [==============================] - 0s 9ms/step
#   Batch 13/42, d_real_loss: 0.6495, d_fake_loss: 0.6182,g_loss: 0.9107
# 4/4 [==============================] - 0s 8ms/step
#   Batch 14/42, d_real_loss: 0.6373, d_fake_loss: 0.6984,g_loss: 0.9527
# 4/4 [==============================] - 0s 9ms/step
#   Batch 15/42, d_real_loss: 0.6136, d_fake_loss: 0.6619,g_loss: 1.0176
# 4/4 [==============================] - 0s 9ms/step
#   Batch 16/42, d_real_loss: 0.6601, d_fake_loss: 0.6517,g_loss: 0.8871
# 4/4 [==============================] - 0s 9ms/step
#   Batch 17/42, d_real_loss: 0.6613, d_fake_loss: 0.6671,g_loss: 0.9477
# 4/4 [==============================] - 0s 10ms/step
#   Batch 18/42, d_real_loss: 0.6338, d_fake_loss: 0.6431,g_loss: 0.9244
# 4/4 [==============================] - 0s 11ms/step
#   Batch 19/42, d_real_loss: 0.6335, d_fake_loss: 0.6988,g_loss: 0.9276
# 4/4 [==============================] - 0s 9ms/step
#   Batch 20/42, d_real_loss: 0.6331, d_fake_loss: 0.6835,g_loss: 0.9044
# 4/4 [==============================] - 0s 9ms/step
#   Batch 21/42, d_real_loss: 0.6668, d_fake_loss: 0.6565,g_loss: 0.9471
# 4/4 [==============================] - 0s 9ms/step
#   Batch 22/42, d_real_loss: 0.6323, d_fake_loss: 0.6230,g_loss: 0.8921
# 4/4 [==============================] - 0s 9ms/step
#   Batch 23/42, d_real_loss: 0.6515, d_fake_loss: 0.7056,g_loss: 0.8180
# 4/4 [==============================] - 0s 9ms/step
#   Batch 24/42, d_real_loss: 0.6300, d_fake_loss: 0.6507,g_loss: 0.9596
# 4/4 [==============================] - 0s 9ms/step
#   Batch 25/42, d_real_loss: 0.6317, d_fake_loss: 0.6638,g_loss: 1.0066
# 4/4 [==============================] - 0s 9ms/step
#   Batch 26/42, d_real_loss: 0.6477, d_fake_loss: 0.6873,g_loss: 0.9323
# 4/4 [==============================] - 0s 9ms/step
#   Batch 27/42, d_real_loss: 0.6336, d_fake_loss: 0.6967,g_loss: 0.9854
# 4/4 [==============================] - 0s 9ms/step
#   Batch 28/42, d_real_loss: 0.6514, d_fake_loss: 0.6618,g_loss: 0.9084
# 4/4 [==============================] - 0s 9ms/step
#   Batch 29/42, d_real_loss: 0.7047, d_fake_loss: 0.6701,g_loss: 0.8779
# 4/4 [==============================] - 0s 9ms/step
#   Batch 30/42, d_real_loss: 0.6308, d_fake_loss: 0.6132,g_loss: 0.9969
# 4/4 [==============================] - 0s 9ms/step
#   Batch 31/42, d_real_loss: 0.6516, d_fake_loss: 0.6895,g_loss: 0.9208
# 4/4 [==============================] - 0s 9ms/step
#   Batch 32/42, d_real_loss: 0.6413, d_fake_loss: 0.6136,g_loss: 0.9418
# 4/4 [==============================] - 0s 9ms/step
#   Batch 33/42, d_real_loss: 0.6386, d_fake_loss: 0.6534,g_loss: 0.8827
# 4/4 [==============================] - 0s 9ms/step
#   Batch 34/42, d_real_loss: 0.6761, d_fake_loss: 0.6957,g_loss: 0.9660
# 4/4 [==============================] - 0s 10ms/step
#   Batch 35/42, d_real_loss: 0.6429, d_fake_loss: 0.6952,g_loss: 0.8546
# 4/4 [==============================] - 0s 9ms/step
#   Batch 36/42, d_real_loss: 0.6326, d_fake_loss: 0.6401,g_loss: 0.9302
# 4/4 [==============================] - 0s 10ms/step
#   Batch 37/42, d_real_loss: 0.6381, d_fake_loss: 0.6570,g_loss: 0.8481
# 4/4 [==============================] - 0s 9ms/step
#   Batch 38/42, d_real_loss: 0.6517, d_fake_loss: 0.6493,g_loss: 0.8718
# 4/4 [==============================] - 0s 9ms/step
#   Batch 39/42, d_real_loss: 0.6619, d_fake_loss: 0.6443,g_loss: 0.9238
# 4/4 [==============================] - 0s 9ms/step
#   Batch 40/42, d_real_loss: 0.6716, d_fake_loss: 0.6463,g_loss: 0.9814
# 4/4 [==============================] - 0s 9ms/step
#   Batch 41/42, d_real_loss: 0.6268, d_fake_loss: 0.6680,g_loss: 0.8657
# 4/4 [==============================] - 0s 9ms/step
#   Batch 42/42, d_real_loss: 0.6124, d_fake_loss: 0.6286,g_loss: 0.9885
# Epoch 43/10000
# 4/4 [==============================] - 0s 9ms/step
#   Batch 1/42, d_real_loss: 0.6352, d_fake_loss: 0.6536,g_loss: 0.9097
# 4/4 [==============================] - 0s 9ms/step
#   Batch 2/42, d_real_loss: 0.6667, d_fake_loss: 0.6810,g_loss: 0.9532
# 4/4 [==============================] - 0s 9ms/step
#   Batch 3/42, d_real_loss: 0.6212, d_fake_loss: 0.6632,g_loss: 0.9781
# 4/4 [==============================] - 0s 9ms/step
#   Batch 4/42, d_real_loss: 0.6191, d_fake_loss: 0.6122,g_loss: 0.8541
# 4/4 [==============================] - 0s 10ms/step
#   Batch 5/42, d_real_loss: 0.6585, d_fake_loss: 0.6991,g_loss: 0.8190
# 4/4 [==============================] - 0s 9ms/step
#   Batch 6/42, d_real_loss: 0.6215, d_fake_loss: 0.6721,g_loss: 0.9084
# 4/4 [==============================] - 0s 9ms/step
#   Batch 7/42, d_real_loss: 0.6382, d_fake_loss: 0.6609,g_loss: 0.8154
# 4/4 [==============================] - 0s 9ms/step
#   Batch 8/42, d_real_loss: 0.6431, d_fake_loss: 0.6603,g_loss: 1.0528
# 4/4 [==============================] - 0s 9ms/step
#   Batch 9/42, d_real_loss: 0.6271, d_fake_loss: 0.6670,g_loss: 0.9437
# 4/4 [==============================] - 0s 9ms/step
#   Batch 10/42, d_real_loss: 0.6164, d_fake_loss: 0.6690,g_loss: 0.9617
# 4/4 [==============================] - 0s 9ms/step
#   Batch 11/42, d_real_loss: 0.6422, d_fake_loss: 0.6544,g_loss: 0.9697
# 4/4 [==============================] - 0s 9ms/step
#   Batch 12/42, d_real_loss: 0.6858, d_fake_loss: 0.6536,g_loss: 0.8896
# 4/4 [==============================] - 0s 9ms/step
#   Batch 13/42, d_real_loss: 0.6507, d_fake_loss: 0.6673,g_loss: 0.8512
# 4/4 [==============================] - 0s 9ms/step
#   Batch 14/42, d_real_loss: 0.6510, d_fake_loss: 0.6595,g_loss: 0.8754
# 4/4 [==============================] - 0s 9ms/step
#   Batch 15/42, d_real_loss: 0.6547, d_fake_loss: 0.6955,g_loss: 1.0055
# 4/4 [==============================] - 0s 9ms/step
#   Batch 16/42, d_real_loss: 0.6333, d_fake_loss: 0.6619,g_loss: 0.8210
# 4/4 [==============================] - 0s 8ms/step
#   Batch 17/42, d_real_loss: 0.6626, d_fake_loss: 0.6525,g_loss: 0.8200
# 4/4 [==============================] - 0s 9ms/step
#   Batch 18/42, d_real_loss: 0.6773, d_fake_loss: 0.6789,g_loss: 0.8557
# 4/4 [==============================] - 0s 9ms/step
#   Batch 19/42, d_real_loss: 0.6240, d_fake_loss: 0.6935,g_loss: 0.7910
# 4/4 [==============================] - 0s 10ms/step
#   Batch 20/42, d_real_loss: 0.6318, d_fake_loss: 0.6683,g_loss: 0.8796
# 4/4 [==============================] - 0s 8ms/step
#   Batch 21/42, d_real_loss: 0.6444, d_fake_loss: 0.6474,g_loss: 0.9472
# 4/4 [==============================] - 0s 9ms/step
#   Batch 22/42, d_real_loss: 0.6414, d_fake_loss: 0.6793,g_loss: 0.9506
# 4/4 [==============================] - 0s 9ms/step
#   Batch 23/42, d_real_loss: 0.6796, d_fake_loss: 0.7243,g_loss: 0.9143
# 4/4 [==============================] - 0s 9ms/step
#   Batch 24/42, d_real_loss: 0.6390, d_fake_loss: 0.6523,g_loss: 0.8543
# 4/4 [==============================] - 0s 8ms/step
#   Batch 25/42, d_real_loss: 0.6526, d_fake_loss: 0.7160,g_loss: 0.8168
# 4/4 [==============================] - 0s 9ms/step
#   Batch 26/42, d_real_loss: 0.6191, d_fake_loss: 0.7018,g_loss: 0.8450
# 4/4 [==============================] - 0s 10ms/step
#   Batch 27/42, d_real_loss: 0.6471, d_fake_loss: 0.6803,g_loss: 0.9195
# 4/4 [==============================] - 0s 9ms/step
#   Batch 28/42, d_real_loss: 0.6409, d_fake_loss: 0.6927,g_loss: 0.9131
# 4/4 [==============================] - 0s 8ms/step
#   Batch 29/42, d_real_loss: 0.6315, d_fake_loss: 0.6485,g_loss: 0.9128
# 4/4 [==============================] - 0s 9ms/step
#   Batch 30/42, d_real_loss: 0.6709, d_fake_loss: 0.6318,g_loss: 0.8663
# 4/4 [==============================] - 0s 9ms/step
#   Batch 31/42, d_real_loss: 0.6499, d_fake_loss: 0.6461,g_loss: 0.9077
# 4/4 [==============================] - 0s 9ms/step
#   Batch 32/42, d_real_loss: 0.6553, d_fake_loss: 0.6840,g_loss: 0.8992
# 4/4 [==============================] - 0s 9ms/step
#   Batch 33/42, d_real_loss: 0.6550, d_fake_loss: 0.6758,g_loss: 0.8159
# 4/4 [==============================] - 0s 9ms/step
#   Batch 34/42, d_real_loss: 0.6546, d_fake_loss: 0.6735,g_loss: 0.8942
# 4/4 [==============================] - 0s 9ms/step
#   Batch 35/42, d_real_loss: 0.6872, d_fake_loss: 0.6629,g_loss: 0.8859
# 4/4 [==============================] - 0s 9ms/step
#   Batch 36/42, d_real_loss: 0.6563, d_fake_loss: 0.6745,g_loss: 0.9305
# 4/4 [==============================] - 0s 9ms/step
#   Batch 37/42, d_real_loss: 0.6467, d_fake_loss: 0.6933,g_loss: 0.8905
# 4/4 [==============================] - 0s 9ms/step
#   Batch 38/42, d_real_loss: 0.6471, d_fake_loss: 0.6650,g_loss: 0.8886
# 4/4 [==============================] - 0s 10ms/step
#   Batch 39/42, d_real_loss: 0.6586, d_fake_loss: 0.6519,g_loss: 0.8849
# 4/4 [==============================] - 0s 9ms/step
#   Batch 40/42, d_real_loss: 0.6537, d_fake_loss: 0.6610,g_loss: 0.8752
# 4/4 [==============================] - 0s 9ms/step
#   Batch 41/42, d_real_loss: 0.6664, d_fake_loss: 0.6671,g_loss: 0.8707
# 4/4 [==============================] - 0s 9ms/step
#   Batch 42/42, d_real_loss: 0.6436, d_fake_loss: 0.6535,g_loss: 0.9267
# Epoch 44/10000
# 4/4 [==============================] - 0s 9ms/step
#   Batch 1/42, d_real_loss: 0.6330, d_fake_loss: 0.6976,g_loss: 0.9650
# 4/4 [==============================] - 0s 9ms/step
#   Batch 2/42, d_real_loss: 0.6543, d_fake_loss: 0.6802,g_loss: 0.9004
# 4/4 [==============================] - 0s 9ms/step
#   Batch 3/42, d_real_loss: 0.6590, d_fake_loss: 0.6245,g_loss: 0.8541
# 4/4 [==============================] - 0s 9ms/step
#   Batch 4/42, d_real_loss: 0.6515, d_fake_loss: 0.6458,g_loss: 0.8036
# 4/4 [==============================] - 0s 9ms/step
#   Batch 5/42, d_real_loss: 0.6631, d_fake_loss: 0.6485,g_loss: 0.8716
# 4/4 [==============================] - 0s 10ms/step
#   Batch 6/42, d_real_loss: 0.6145, d_fake_loss: 0.6514,g_loss: 0.8257
# 4/4 [==============================] - 0s 9ms/step
#   Batch 7/42, d_real_loss: 0.6512, d_fake_loss: 0.6291,g_loss: 0.8733
# 4/4 [==============================] - 0s 9ms/step
#   Batch 8/42, d_real_loss: 0.6644, d_fake_loss: 0.6703,g_loss: 1.0727
# 4/4 [==============================] - 0s 9ms/step
#   Batch 9/42, d_real_loss: 0.6633, d_fake_loss: 0.6495,g_loss: 0.8261
# 4/4 [==============================] - 0s 9ms/step
#   Batch 10/42, d_real_loss: 0.6143, d_fake_loss: 0.6675,g_loss: 0.9303
# 4/4 [==============================] - 0s 9ms/step
#   Batch 11/42, d_real_loss: 0.6529, d_fake_loss: 0.6900,g_loss: 0.9245
# 4/4 [==============================] - 0s 9ms/step
#   Batch 12/42, d_real_loss: 0.6385, d_fake_loss: 0.6542,g_loss: 0.9172
# 4/4 [==============================] - 0s 9ms/step
#   Batch 13/42, d_real_loss: 0.6263, d_fake_loss: 0.6686,g_loss: 0.9493
# 4/4 [==============================] - 0s 9ms/step
#   Batch 14/42, d_real_loss: 0.6396, d_fake_loss: 0.6776,g_loss: 0.8316
# 4/4 [==============================] - 0s 9ms/step
#   Batch 15/42, d_real_loss: 0.6250, d_fake_loss: 0.6349,g_loss: 0.8367
# 4/4 [==============================] - 0s 9ms/step
#   Batch 16/42, d_real_loss: 0.6529, d_fake_loss: 0.6081,g_loss: 0.8538
# 4/4 [==============================] - 0s 9ms/step
#   Batch 17/42, d_real_loss: 0.6324, d_fake_loss: 0.7007,g_loss: 0.8508
# 4/4 [==============================] - 0s 9ms/step
#   Batch 18/42, d_real_loss: 0.6296, d_fake_loss: 0.6642,g_loss: 0.9176
# 4/4 [==============================] - 0s 9ms/step
#   Batch 19/42, d_real_loss: 0.6874, d_fake_loss: 0.6441,g_loss: 0.8880
# 4/4 [==============================] - 0s 9ms/step
#   Batch 20/42, d_real_loss: 0.6160, d_fake_loss: 0.6118,g_loss: 0.9061
# 4/4 [==============================] - 0s 9ms/step
#   Batch 21/42, d_real_loss: 0.6567, d_fake_loss: 0.6557,g_loss: 0.8332
# 4/4 [==============================] - 0s 9ms/step
#   Batch 22/42, d_real_loss: 0.6444, d_fake_loss: 0.6678,g_loss: 0.9867
# 4/4 [==============================] - 0s 9ms/step
#   Batch 23/42, d_real_loss: 0.6481, d_fake_loss: 0.6970,g_loss: 1.0147
# 4/4 [==============================] - 0s 9ms/step
#   Batch 24/42, d_real_loss: 0.6344, d_fake_loss: 0.7044,g_loss: 0.9814
# 4/4 [==============================] - 0s 9ms/step
#   Batch 25/42, d_real_loss: 0.6322, d_fake_loss: 0.6554,g_loss: 0.8768
# 4/4 [==============================] - 0s 11ms/step
#   Batch 26/42, d_real_loss: 0.6342, d_fake_loss: 0.6987,g_loss: 0.9309
# 4/4 [==============================] - 0s 11ms/step
#   Batch 27/42, d_real_loss: 0.6837, d_fake_loss: 0.6506,g_loss: 1.0336
# 4/4 [==============================] - 0s 9ms/step
#   Batch 28/42, d_real_loss: 0.7036, d_fake_loss: 0.6587,g_loss: 0.9740
# 4/4 [==============================] - 0s 9ms/step
#   Batch 29/42, d_real_loss: 0.6753, d_fake_loss: 0.6239,g_loss: 0.7527
# 4/4 [==============================] - 0s 9ms/step
#   Batch 30/42, d_real_loss: 0.6506, d_fake_loss: 0.6804,g_loss: 0.9070
# 4/4 [==============================] - 0s 8ms/step
#   Batch 31/42, d_real_loss: 0.6398, d_fake_loss: 0.6510,g_loss: 0.8522
# 4/4 [==============================] - 0s 10ms/step
#   Batch 32/42, d_real_loss: 0.6230, d_fake_loss: 0.6598,g_loss: 0.9864
# 4/4 [==============================] - 0s 11ms/step
#   Batch 33/42, d_real_loss: 0.6737, d_fake_loss: 0.6662,g_loss: 0.8897
# 4/4 [==============================] - 0s 9ms/step
#   Batch 34/42, d_real_loss: 0.6416, d_fake_loss: 0.6229,g_loss: 0.7826
# 4/4 [==============================] - 0s 9ms/step
#   Batch 35/42, d_real_loss: 0.6391, d_fake_loss: 0.6847,g_loss: 0.8518
# 4/4 [==============================] - 0s 9ms/step
#   Batch 36/42, d_real_loss: 0.6314, d_fake_loss: 0.6445,g_loss: 0.9309
# 4/4 [==============================] - 0s 10ms/step
#   Batch 37/42, d_real_loss: 0.6908, d_fake_loss: 0.6318,g_loss: 0.8950
# 4/4 [==============================] - 0s 9ms/step
#   Batch 38/42, d_real_loss: 0.7202, d_fake_loss: 0.6100,g_loss: 0.9303
# 4/4 [==============================] - 0s 8ms/step
#   Batch 39/42, d_real_loss: 0.6889, d_fake_loss: 0.7044,g_loss: 0.8462
# 4/4 [==============================] - 0s 9ms/step
#   Batch 40/42, d_real_loss: 0.6598, d_fake_loss: 0.6504,g_loss: 0.8511
# 4/4 [==============================] - 0s 9ms/step
#   Batch 41/42, d_real_loss: 0.6594, d_fake_loss: 0.6763,g_loss: 0.9127
# 4/4 [==============================] - 0s 9ms/step
#   Batch 42/42, d_real_loss: 0.6529, d_fake_loss: 0.6416,g_loss: 0.9333
# Epoch 45/10000
# 4/4 [==============================] - 0s 9ms/step
#   Batch 1/42, d_real_loss: 0.6376, d_fake_loss: 0.6496,g_loss: 0.8756
# 4/4 [==============================] - 0s 10ms/step
#   Batch 2/42, d_real_loss: 0.6494, d_fake_loss: 0.7175,g_loss: 0.8501
# 4/4 [==============================] - 0s 9ms/step
#   Batch 3/42, d_real_loss: 0.6354, d_fake_loss: 0.6483,g_loss: 0.7994
# 4/4 [==============================] - 0s 9ms/step
#   Batch 4/42, d_real_loss: 0.6266, d_fake_loss: 0.6652,g_loss: 0.8539
# 4/4 [==============================] - 0s 10ms/step
#   Batch 5/42, d_real_loss: 0.6495, d_fake_loss: 0.6957,g_loss: 0.8767
# 4/4 [==============================] - 0s 9ms/step
#   Batch 6/42, d_real_loss: 0.6413, d_fake_loss: 0.6611,g_loss: 0.8377
# 4/4 [==============================] - 0s 9ms/step
#   Batch 7/42, d_real_loss: 0.6230, d_fake_loss: 0.6286,g_loss: 0.8076
# 4/4 [==============================] - 0s 10ms/step
#   Batch 8/42, d_real_loss: 0.6240, d_fake_loss: 0.6861,g_loss: 0.8716
# 4/4 [==============================] - 0s 9ms/step
#   Batch 9/42, d_real_loss: 0.5969, d_fake_loss: 0.6653,g_loss: 0.9635
# 4/4 [==============================] - 0s 9ms/step
#   Batch 10/42, d_real_loss: 0.6604, d_fake_loss: 0.6737,g_loss: 0.8676
# 4/4 [==============================] - 0s 9ms/step
#   Batch 11/42, d_real_loss: 0.6565, d_fake_loss: 0.6393,g_loss: 0.9214
# 4/4 [==============================] - 0s 9ms/step
#   Batch 12/42, d_real_loss: 0.6238, d_fake_loss: 0.6602,g_loss: 0.8320
# 4/4 [==============================] - 0s 9ms/step
#   Batch 13/42, d_real_loss: 0.6574, d_fake_loss: 0.6561,g_loss: 1.0350
# 4/4 [==============================] - 0s 9ms/step
#   Batch 14/42, d_real_loss: 0.6344, d_fake_loss: 0.6320,g_loss: 0.9253
# 4/4 [==============================] - 0s 9ms/step
#   Batch 15/42, d_real_loss: 0.6314, d_fake_loss: 0.6299,g_loss: 0.8521
# 4/4 [==============================] - 0s 9ms/step
#   Batch 16/42, d_real_loss: 0.6842, d_fake_loss: 0.6429,g_loss: 0.9549
# 4/4 [==============================] - 0s 9ms/step
#   Batch 17/42, d_real_loss: 0.6496, d_fake_loss: 0.6090,g_loss: 0.8547
# 4/4 [==============================] - 0s 9ms/step
#   Batch 18/42, d_real_loss: 0.6321, d_fake_loss: 0.6980,g_loss: 0.9523
# 4/4 [==============================] - 0s 9ms/step
#   Batch 19/42, d_real_loss: 0.6237, d_fake_loss: 0.6706,g_loss: 0.9760
# 4/4 [==============================] - 0s 9ms/step
#   Batch 20/42, d_real_loss: 0.6441, d_fake_loss: 0.7085,g_loss: 0.9069
# 4/4 [==============================] - 0s 9ms/step
#   Batch 21/42, d_real_loss: 0.6216, d_fake_loss: 0.6660,g_loss: 0.9643
# 4/4 [==============================] - 0s 9ms/step
#   Batch 22/42, d_real_loss: 0.6625, d_fake_loss: 0.6666,g_loss: 0.8321
# 4/4 [==============================] - 0s 9ms/step
#   Batch 23/42, d_real_loss: 0.6317, d_fake_loss: 0.6983,g_loss: 0.8724
# 4/4 [==============================] - 0s 9ms/step
#   Batch 24/42, d_real_loss: 0.6427, d_fake_loss: 0.6593,g_loss: 0.9726
# 4/4 [==============================] - 0s 9ms/step
#   Batch 25/42, d_real_loss: 0.6305, d_fake_loss: 0.7009,g_loss: 0.9226
# 4/4 [==============================] - 0s 9ms/step
#   Batch 26/42, d_real_loss: 0.6469, d_fake_loss: 0.6844,g_loss: 0.7851
# 4/4 [==============================] - 0s 8ms/step
#   Batch 27/42, d_real_loss: 0.6515, d_fake_loss: 0.6395,g_loss: 0.8742
# 4/4 [==============================] - 0s 9ms/step
#   Batch 28/42, d_real_loss: 0.6382, d_fake_loss: 0.6276,g_loss: 0.9051
# 4/4 [==============================] - 0s 10ms/step
#   Batch 29/42, d_real_loss: 0.6247, d_fake_loss: 0.5983,g_loss: 1.0428
# 4/4 [==============================] - 0s 9ms/step
#   Batch 30/42, d_real_loss: 0.6407, d_fake_loss: 0.6726,g_loss: 0.9502
# 4/4 [==============================] - 0s 8ms/step
#   Batch 31/42, d_real_loss: 0.6609, d_fake_loss: 0.6731,g_loss: 0.9021
# 4/4 [==============================] - 0s 9ms/step
#   Batch 32/42, d_real_loss: 0.6384, d_fake_loss: 0.6188,g_loss: 0.9853
# 4/4 [==============================] - 0s 9ms/step
#   Batch 33/42, d_real_loss: 0.6451, d_fake_loss: 0.6616,g_loss: 1.0205
# 4/4 [==============================] - 0s 10ms/step
#   Batch 34/42, d_real_loss: 0.6392, d_fake_loss: 0.6526,g_loss: 1.0228
# 4/4 [==============================] - 0s 9ms/step
#   Batch 35/42, d_real_loss: 0.6371, d_fake_loss: 0.6509,g_loss: 0.9604
# 4/4 [==============================] - 0s 9ms/step
#   Batch 36/42, d_real_loss: 0.6394, d_fake_loss: 0.7179,g_loss: 1.0080
# 4/4 [==============================] - 0s 9ms/step
#   Batch 37/42, d_real_loss: 0.6759, d_fake_loss: 0.6461,g_loss: 0.8590
# 4/4 [==============================] - 0s 11ms/step
#   Batch 38/42, d_real_loss: 0.6413, d_fake_loss: 0.6530,g_loss: 0.9299
# 4/4 [==============================] - 0s 10ms/step
#   Batch 39/42, d_real_loss: 0.6516, d_fake_loss: 0.6179,g_loss: 0.9208
# 4/4 [==============================] - 0s 8ms/step
#   Batch 40/42, d_real_loss: 0.6570, d_fake_loss: 0.6458,g_loss: 0.9233
# 4/4 [==============================] - 0s 9ms/step
#   Batch 41/42, d_real_loss: 0.6269, d_fake_loss: 0.6554,g_loss: 0.9467
# 4/4 [==============================] - 0s 9ms/step
#   Batch 42/42, d_real_loss: 0.6096, d_fake_loss: 0.7185,g_loss: 0.8925
# Epoch 46/10000
# 4/4 [==============================] - 0s 8ms/step
#   Batch 1/42, d_real_loss: 0.6299, d_fake_loss: 0.6533,g_loss: 0.9908
# 4/4 [==============================] - 0s 8ms/step
#   Batch 2/42, d_real_loss: 0.6888, d_fake_loss: 0.6495,g_loss: 0.8881
# 4/4 [==============================] - 0s 9ms/step
#   Batch 3/42, d_real_loss: 0.6215, d_fake_loss: 0.6069,g_loss: 0.9812
# 4/4 [==============================] - 0s 8ms/step
#   Batch 4/42, d_real_loss: 0.5981, d_fake_loss: 0.6698,g_loss: 0.9846
# 4/4 [==============================] - 0s 8ms/step
#   Batch 5/42, d_real_loss: 0.6086, d_fake_loss: 0.6655,g_loss: 0.9477
# 4/4 [==============================] - 0s 9ms/step
#   Batch 6/42, d_real_loss: 0.5950, d_fake_loss: 0.6595,g_loss: 0.9522
# 4/4 [==============================] - 0s 9ms/step
#   Batch 7/42, d_real_loss: 0.6495, d_fake_loss: 0.6986,g_loss: 1.0044
# 4/4 [==============================] - 0s 9ms/step
#   Batch 8/42, d_real_loss: 0.6260, d_fake_loss: 0.6554,g_loss: 0.8782
# 4/4 [==============================] - 0s 9ms/step
#   Batch 9/42, d_real_loss: 0.6365, d_fake_loss: 0.6334,g_loss: 1.0698
# 4/4 [==============================] - 0s 9ms/step
#   Batch 10/42, d_real_loss: 0.6354, d_fake_loss: 0.6162,g_loss: 0.9969
# 4/4 [==============================] - 0s 9ms/step
#   Batch 11/42, d_real_loss: 0.6780, d_fake_loss: 0.6650,g_loss: 0.9552
# 4/4 [==============================] - 0s 10ms/step
#   Batch 12/42, d_real_loss: 0.6391, d_fake_loss: 0.6661,g_loss: 0.9641
# 4/4 [==============================] - 0s 9ms/step
#   Batch 13/42, d_real_loss: 0.6384, d_fake_loss: 0.7287,g_loss: 0.8827
# 4/4 [==============================] - 0s 10ms/step
#   Batch 14/42, d_real_loss: 0.6152, d_fake_loss: 0.6499,g_loss: 0.8576
# 4/4 [==============================] - 0s 9ms/step
#   Batch 15/42, d_real_loss: 0.6543, d_fake_loss: 0.6698,g_loss: 0.9654
# 4/4 [==============================] - 0s 9ms/step
#   Batch 16/42, d_real_loss: 0.6225, d_fake_loss: 0.6433,g_loss: 0.9455
# 4/4 [==============================] - 0s 9ms/step
#   Batch 17/42, d_real_loss: 0.6308, d_fake_loss: 0.6318,g_loss: 0.8353
# 4/4 [==============================] - 0s 9ms/step
#   Batch 18/42, d_real_loss: 0.6650, d_fake_loss: 0.7034,g_loss: 0.8809
# 4/4 [==============================] - 0s 9ms/step
#   Batch 19/42, d_real_loss: 0.6611, d_fake_loss: 0.6738,g_loss: 0.8709
# 4/4 [==============================] - 0s 10ms/step
#   Batch 20/42, d_real_loss: 0.6310, d_fake_loss: 0.6658,g_loss: 0.9663
# 4/4 [==============================] - 0s 9ms/step
#   Batch 21/42, d_real_loss: 0.6376, d_fake_loss: 0.6382,g_loss: 0.8143
# 4/4 [==============================] - 0s 9ms/step
#   Batch 22/42, d_real_loss: 0.6481, d_fake_loss: 0.6619,g_loss: 0.9108
# 4/4 [==============================] - 0s 8ms/step
#   Batch 23/42, d_real_loss: 0.6756, d_fake_loss: 0.6851,g_loss: 0.8513
# 4/4 [==============================] - 0s 9ms/step
#   Batch 24/42, d_real_loss: 0.6675, d_fake_loss: 0.6761,g_loss: 0.9212
# 4/4 [==============================] - 0s 9ms/step
#   Batch 25/42, d_real_loss: 0.6554, d_fake_loss: 0.6714,g_loss: 0.8705
# 4/4 [==============================] - 0s 9ms/step
#   Batch 26/42, d_real_loss: 0.6508, d_fake_loss: 0.6560,g_loss: 0.9724
# 4/4 [==============================] - 0s 10ms/step
#   Batch 27/42, d_real_loss: 0.6361, d_fake_loss: 0.7144,g_loss: 0.9124
# 4/4 [==============================] - 0s 9ms/step
#   Batch 28/42, d_real_loss: 0.6765, d_fake_loss: 0.6713,g_loss: 0.8721
# 4/4 [==============================] - 0s 9ms/step
#   Batch 29/42, d_real_loss: 0.6468, d_fake_loss: 0.6798,g_loss: 0.9593
# 4/4 [==============================] - 0s 9ms/step
#   Batch 30/42, d_real_loss: 0.6501, d_fake_loss: 0.6435,g_loss: 0.9305
# 4/4 [==============================] - 0s 9ms/step
#   Batch 31/42, d_real_loss: 0.6697, d_fake_loss: 0.6498,g_loss: 0.9508
# 4/4 [==============================] - 0s 9ms/step
#   Batch 32/42, d_real_loss: 0.6680, d_fake_loss: 0.6342,g_loss: 0.9281
# 4/4 [==============================] - 0s 9ms/step
#   Batch 33/42, d_real_loss: 0.6551, d_fake_loss: 0.6744,g_loss: 0.9703
# 4/4 [==============================] - 0s 9ms/step
#   Batch 34/42, d_real_loss: 0.6607, d_fake_loss: 0.6291,g_loss: 0.8901
# 4/4 [==============================] - 0s 9ms/step
#   Batch 35/42, d_real_loss: 0.6645, d_fake_loss: 0.6406,g_loss: 0.8518
# 4/4 [==============================] - 0s 9ms/step
#   Batch 36/42, d_real_loss: 0.6336, d_fake_loss: 0.6352,g_loss: 0.8376
# 4/4 [==============================] - 0s 9ms/step
#   Batch 37/42, d_real_loss: 0.6096, d_fake_loss: 0.6869,g_loss: 0.9705
# 4/4 [==============================] - 0s 9ms/step
#   Batch 38/42, d_real_loss: 0.6687, d_fake_loss: 0.6194,g_loss: 0.9328
# 4/4 [==============================] - 0s 9ms/step
#   Batch 39/42, d_real_loss: 0.6569, d_fake_loss: 0.6665,g_loss: 0.8651
# 4/4 [==============================] - 0s 9ms/step
#   Batch 40/42, d_real_loss: 0.6249, d_fake_loss: 0.6257,g_loss: 0.9300
# 4/4 [==============================] - 0s 9ms/step
#   Batch 41/42, d_real_loss: 0.6536, d_fake_loss: 0.6707,g_loss: 0.9092
# 4/4 [==============================] - 0s 10ms/step
#   Batch 42/42, d_real_loss: 0.6641, d_fake_loss: 0.6606,g_loss: 0.8595
# Epoch 47/10000
# 4/4 [==============================] - 0s 9ms/step
#   Batch 1/42, d_real_loss: 0.6885, d_fake_loss: 0.7061,g_loss: 0.8952
# 4/4 [==============================] - 0s 9ms/step
#   Batch 2/42, d_real_loss: 0.6344, d_fake_loss: 0.6325,g_loss: 0.8386
# 4/4 [==============================] - 0s 9ms/step
#   Batch 3/42, d_real_loss: 0.6517, d_fake_loss: 0.7011,g_loss: 0.9047
# 4/4 [==============================] - 0s 9ms/step
#   Batch 4/42, d_real_loss: 0.6438, d_fake_loss: 0.6172,g_loss: 0.9106
# 4/4 [==============================] - 0s 10ms/step
#   Batch 5/42, d_real_loss: 0.6479, d_fake_loss: 0.6400,g_loss: 0.8428
# 4/4 [==============================] - 0s 9ms/step
#   Batch 6/42, d_real_loss: 0.6169, d_fake_loss: 0.6725,g_loss: 0.8984
# 4/4 [==============================] - 0s 9ms/step
#   Batch 7/42, d_real_loss: 0.6643, d_fake_loss: 0.6521,g_loss: 0.8530
# 4/4 [==============================] - 0s 9ms/step
#   Batch 8/42, d_real_loss: 0.6212, d_fake_loss: 0.6839,g_loss: 0.8042
# 4/4 [==============================] - 0s 9ms/step
#   Batch 9/42, d_real_loss: 0.6727, d_fake_loss: 0.6259,g_loss: 0.8592
# 4/4 [==============================] - 0s 9ms/step
#   Batch 10/42, d_real_loss: 0.6367, d_fake_loss: 0.6853,g_loss: 0.9238
# 4/4 [==============================] - 0s 9ms/step
#   Batch 11/42, d_real_loss: 0.6848, d_fake_loss: 0.6389,g_loss: 0.9188
# 4/4 [==============================] - 0s 9ms/step
#   Batch 12/42, d_real_loss: 0.6729, d_fake_loss: 0.6615,g_loss: 0.8519
# 4/4 [==============================] - 0s 9ms/step
#   Batch 13/42, d_real_loss: 0.6207, d_fake_loss: 0.6700,g_loss: 0.8957
# 4/4 [==============================] - 0s 9ms/step
#   Batch 14/42, d_real_loss: 0.5997, d_fake_loss: 0.6231,g_loss: 0.9208
# 4/4 [==============================] - 0s 9ms/step
#   Batch 15/42, d_real_loss: 0.6410, d_fake_loss: 0.6651,g_loss: 0.8638
# 4/4 [==============================] - 0s 9ms/step
#   Batch 16/42, d_real_loss: 0.6624, d_fake_loss: 0.6947,g_loss: 0.9173
# 4/4 [==============================] - 0s 9ms/step
#   Batch 17/42, d_real_loss: 0.6906, d_fake_loss: 0.6387,g_loss: 0.8597
# 4/4 [==============================] - 0s 9ms/step
#   Batch 18/42, d_real_loss: 0.6372, d_fake_loss: 0.6429,g_loss: 0.8915
# 4/4 [==============================] - 0s 9ms/step
#   Batch 19/42, d_real_loss: 0.6817, d_fake_loss: 0.6422,g_loss: 0.9978
# 4/4 [==============================] - 0s 9ms/step
#   Batch 20/42, d_real_loss: 0.6318, d_fake_loss: 0.6919,g_loss: 0.8843
# 4/4 [==============================] - 0s 9ms/step
#   Batch 21/42, d_real_loss: 0.6413, d_fake_loss: 0.6755,g_loss: 0.9202
# 4/4 [==============================] - 0s 9ms/step
#   Batch 22/42, d_real_loss: 0.6517, d_fake_loss: 0.6753,g_loss: 0.8694
# 4/4 [==============================] - 0s 10ms/step
#   Batch 23/42, d_real_loss: 0.6376, d_fake_loss: 0.6962,g_loss: 0.9164
# 4/4 [==============================] - 0s 9ms/step
#   Batch 24/42, d_real_loss: 0.6161, d_fake_loss: 0.6898,g_loss: 0.8974
# 4/4 [==============================] - 0s 9ms/step
#   Batch 25/42, d_real_loss: 0.6336, d_fake_loss: 0.6629,g_loss: 0.8607
# 4/4 [==============================] - 0s 9ms/step
#   Batch 26/42, d_real_loss: 0.6545, d_fake_loss: 0.6891,g_loss: 0.9328
# 4/4 [==============================] - 0s 9ms/step
#   Batch 27/42, d_real_loss: 0.6577, d_fake_loss: 0.6686,g_loss: 0.9421
# 4/4 [==============================] - 0s 9ms/step
#   Batch 28/42, d_real_loss: 0.6587, d_fake_loss: 0.6487,g_loss: 0.9035
# 4/4 [==============================] - 0s 9ms/step
#   Batch 29/42, d_real_loss: 0.6360, d_fake_loss: 0.6760,g_loss: 0.8917
# 4/4 [==============================] - 0s 9ms/step
#   Batch 30/42, d_real_loss: 0.6405, d_fake_loss: 0.6692,g_loss: 0.9042
# 4/4 [==============================] - 0s 9ms/step
#   Batch 31/42, d_real_loss: 0.7053, d_fake_loss: 0.6589,g_loss: 0.8324
# 4/4 [==============================] - 0s 9ms/step
#   Batch 32/42, d_real_loss: 0.6484, d_fake_loss: 0.6714,g_loss: 0.8903
# 4/4 [==============================] - 0s 9ms/step
#   Batch 33/42, d_real_loss: 0.6361, d_fake_loss: 0.6438,g_loss: 0.8694
# 4/4 [==============================] - 0s 9ms/step
#   Batch 34/42, d_real_loss: 0.6320, d_fake_loss: 0.6634,g_loss: 0.9588
# 4/4 [==============================] - 0s 9ms/step
#   Batch 35/42, d_real_loss: 0.6354, d_fake_loss: 0.6666,g_loss: 0.8431
# 4/4 [==============================] - 0s 9ms/step
#   Batch 36/42, d_real_loss: 0.6556, d_fake_loss: 0.6866,g_loss: 0.9560
# 4/4 [==============================] - 0s 9ms/step
#   Batch 37/42, d_real_loss: 0.6554, d_fake_loss: 0.6905,g_loss: 0.9392
# 4/4 [==============================] - 0s 9ms/step
#   Batch 38/42, d_real_loss: 0.6381, d_fake_loss: 0.6796,g_loss: 0.8573
# 4/4 [==============================] - 0s 9ms/step
#   Batch 39/42, d_real_loss: 0.6668, d_fake_loss: 0.6556,g_loss: 1.0243
# 4/4 [==============================] - 0s 9ms/step
#   Batch 40/42, d_real_loss: 0.6507, d_fake_loss: 0.6599,g_loss: 0.9524
# 4/4 [==============================] - 0s 9ms/step
#   Batch 41/42, d_real_loss: 0.6549, d_fake_loss: 0.6497,g_loss: 0.9090
# 4/4 [==============================] - 0s 9ms/step
#   Batch 42/42, d_real_loss: 0.6414, d_fake_loss: 0.6794,g_loss: 0.9021
# Epoch 48/10000
# 4/4 [==============================] - 0s 8ms/step
#   Batch 1/42, d_real_loss: 0.6377, d_fake_loss: 0.6646,g_loss: 0.8757
# 4/4 [==============================] - 0s 9ms/step
#   Batch 2/42, d_real_loss: 0.6338, d_fake_loss: 0.6474,g_loss: 0.9336
# 4/4 [==============================] - 0s 9ms/step
#   Batch 3/42, d_real_loss: 0.6877, d_fake_loss: 0.6963,g_loss: 0.9749
# 4/4 [==============================] - 0s 9ms/step
#   Batch 4/42, d_real_loss: 0.6482, d_fake_loss: 0.6913,g_loss: 0.8566
# 4/4 [==============================] - 0s 9ms/step
#   Batch 5/42, d_real_loss: 0.6391, d_fake_loss: 0.6794,g_loss: 0.9648
# 4/4 [==============================] - 0s 9ms/step
#   Batch 6/42, d_real_loss: 0.6389, d_fake_loss: 0.6523,g_loss: 0.8606
# 4/4 [==============================] - 0s 9ms/step
#   Batch 7/42, d_real_loss: 0.6366, d_fake_loss: 0.6687,g_loss: 0.9359
# 4/4 [==============================] - 0s 9ms/step
#   Batch 8/42, d_real_loss: 0.6455, d_fake_loss: 0.6974,g_loss: 0.8682
# 4/4 [==============================] - 0s 9ms/step
#   Batch 9/42, d_real_loss: 0.6101, d_fake_loss: 0.6799,g_loss: 0.8517
# 4/4 [==============================] - 0s 9ms/step
#   Batch 10/42, d_real_loss: 0.6229, d_fake_loss: 0.6366,g_loss: 0.8800
# 4/4 [==============================] - 0s 9ms/step
#   Batch 11/42, d_real_loss: 0.6580, d_fake_loss: 0.6614,g_loss: 0.9338
# 4/4 [==============================] - 0s 9ms/step
#   Batch 12/42, d_real_loss: 0.6801, d_fake_loss: 0.6742,g_loss: 0.9173
# 4/4 [==============================] - 0s 9ms/step
#   Batch 13/42, d_real_loss: 0.6762, d_fake_loss: 0.6548,g_loss: 0.8510
# 4/4 [==============================] - 0s 10ms/step
#   Batch 14/42, d_real_loss: 0.6544, d_fake_loss: 0.6750,g_loss: 0.9373
# 4/4 [==============================] - 0s 10ms/step
#   Batch 15/42, d_real_loss: 0.6464, d_fake_loss: 0.6317,g_loss: 0.9236
# 4/4 [==============================] - 0s 9ms/step
#   Batch 16/42, d_real_loss: 0.6346, d_fake_loss: 0.6620,g_loss: 0.9337
# 4/4 [==============================] - 0s 9ms/step
#   Batch 17/42, d_real_loss: 0.6199, d_fake_loss: 0.6563,g_loss: 0.9376
# 4/4 [==============================] - 0s 8ms/step
#   Batch 18/42, d_real_loss: 0.6408, d_fake_loss: 0.6741,g_loss: 0.8898
# 4/4 [==============================] - 0s 9ms/step
#   Batch 19/42, d_real_loss: 0.6558, d_fake_loss: 0.6671,g_loss: 0.9374
# 4/4 [==============================] - 0s 9ms/step
#   Batch 20/42, d_real_loss: 0.6571, d_fake_loss: 0.6455,g_loss: 0.9040
# 4/4 [==============================] - 0s 9ms/step
#   Batch 21/42, d_real_loss: 0.6479, d_fake_loss: 0.6905,g_loss: 0.7806
# 4/4 [==============================] - 0s 9ms/step
#   Batch 22/42, d_real_loss: 0.6211, d_fake_loss: 0.6482,g_loss: 0.9058
# 4/4 [==============================] - 0s 9ms/step
#   Batch 23/42, d_real_loss: 0.6495, d_fake_loss: 0.7071,g_loss: 0.8872
# 4/4 [==============================] - 0s 10ms/step
#   Batch 24/42, d_real_loss: 0.6294, d_fake_loss: 0.6155,g_loss: 0.9170
# 4/4 [==============================] - 0s 9ms/step
#   Batch 25/42, d_real_loss: 0.6031, d_fake_loss: 0.6449,g_loss: 0.9023
# 4/4 [==============================] - 0s 9ms/step
#   Batch 26/42, d_real_loss: 0.7019, d_fake_loss: 0.7104,g_loss: 0.9548
# 4/4 [==============================] - 0s 9ms/step
#   Batch 27/42, d_real_loss: 0.6384, d_fake_loss: 0.6769,g_loss: 0.8685
# 4/4 [==============================] - 0s 9ms/step
#   Batch 28/42, d_real_loss: 0.6382, d_fake_loss: 0.6543,g_loss: 0.8815
# 4/4 [==============================] - 0s 9ms/step
#   Batch 29/42, d_real_loss: 0.6091, d_fake_loss: 0.6617,g_loss: 0.9323
# 4/4 [==============================] - 0s 9ms/step
#   Batch 30/42, d_real_loss: 0.6381, d_fake_loss: 0.6240,g_loss: 0.8763
# 4/4 [==============================] - 0s 10ms/step
#   Batch 31/42, d_real_loss: 0.6555, d_fake_loss: 0.6281,g_loss: 0.8562
# 4/4 [==============================] - 0s 9ms/step
#   Batch 32/42, d_real_loss: 0.6435, d_fake_loss: 0.6773,g_loss: 0.9260
# 4/4 [==============================] - 0s 9ms/step
#   Batch 33/42, d_real_loss: 0.6518, d_fake_loss: 0.6640,g_loss: 0.7625
# 4/4 [==============================] - 0s 9ms/step
#   Batch 34/42, d_real_loss: 0.6819, d_fake_loss: 0.5881,g_loss: 0.9819
# 4/4 [==============================] - 0s 10ms/step
#   Batch 35/42, d_real_loss: 0.6361, d_fake_loss: 0.6485,g_loss: 0.8766
# 4/4 [==============================] - 0s 9ms/step
#   Batch 36/42, d_real_loss: 0.6276, d_fake_loss: 0.6303,g_loss: 0.8914
# 4/4 [==============================] - 0s 9ms/step
#   Batch 37/42, d_real_loss: 0.6727, d_fake_loss: 0.7001,g_loss: 1.0162
# 4/4 [==============================] - 0s 10ms/step
#   Batch 38/42, d_real_loss: 0.6379, d_fake_loss: 0.6521,g_loss: 0.8593
# 4/4 [==============================] - 0s 9ms/step
#   Batch 39/42, d_real_loss: 0.6338, d_fake_loss: 0.6973,g_loss: 0.9633
# 4/4 [==============================] - 0s 9ms/step
#   Batch 40/42, d_real_loss: 0.6237, d_fake_loss: 0.7134,g_loss: 1.0834
# 4/4 [==============================] - 0s 9ms/step
#   Batch 41/42, d_real_loss: 0.6367, d_fake_loss: 0.6642,g_loss: 0.9351
# 4/4 [==============================] - 0s 9ms/step
#   Batch 42/42, d_real_loss: 0.6440, d_fake_loss: 0.6791,g_loss: 0.8423
# Epoch 49/10000
# 4/4 [==============================] - 0s 9ms/step
#   Batch 1/42, d_real_loss: 0.6271, d_fake_loss: 0.6381,g_loss: 0.9082
# 4/4 [==============================] - 0s 9ms/step
#   Batch 2/42, d_real_loss: 0.6322, d_fake_loss: 0.6971,g_loss: 0.9155
# 4/4 [==============================] - 0s 9ms/step
#   Batch 3/42, d_real_loss: 0.6407, d_fake_loss: 0.6687,g_loss: 0.8896
# 4/4 [==============================] - 0s 9ms/step
#   Batch 4/42, d_real_loss: 0.6426, d_fake_loss: 0.6618,g_loss: 0.8728
# 4/4 [==============================] - 0s 9ms/step
#   Batch 5/42, d_real_loss: 0.6621, d_fake_loss: 0.6485,g_loss: 0.9415
# 4/4 [==============================] - 0s 9ms/step
#   Batch 6/42, d_real_loss: 0.6401, d_fake_loss: 0.6661,g_loss: 0.9683
# 4/4 [==============================] - 0s 9ms/step
#   Batch 7/42, d_real_loss: 0.6534, d_fake_loss: 0.6644,g_loss: 0.9134
# 4/4 [==============================] - 0s 9ms/step
#   Batch 8/42, d_real_loss: 0.6762, d_fake_loss: 0.6952,g_loss: 0.8438
# 4/4 [==============================] - 0s 9ms/step
#   Batch 9/42, d_real_loss: 0.6322, d_fake_loss: 0.7057,g_loss: 0.9127
# 4/4 [==============================] - 0s 9ms/step
#   Batch 10/42, d_real_loss: 0.6683, d_fake_loss: 0.6755,g_loss: 0.8720
# 4/4 [==============================] - 0s 9ms/step
#   Batch 11/42, d_real_loss: 0.6483, d_fake_loss: 0.6761,g_loss: 0.8519
# 4/4 [==============================] - 0s 9ms/step
#   Batch 12/42, d_real_loss: 0.6331, d_fake_loss: 0.6587,g_loss: 0.7873
# 4/4 [==============================] - 0s 9ms/step
#   Batch 13/42, d_real_loss: 0.6316, d_fake_loss: 0.6517,g_loss: 0.9468
# 4/4 [==============================] - 0s 9ms/step
#   Batch 14/42, d_real_loss: 0.6615, d_fake_loss: 0.6464,g_loss: 0.8938
# 4/4 [==============================] - 0s 9ms/step
#   Batch 15/42, d_real_loss: 0.6552, d_fake_loss: 0.6474,g_loss: 0.8764
# 4/4 [==============================] - 0s 9ms/step
#   Batch 16/42, d_real_loss: 0.6384, d_fake_loss: 0.6881,g_loss: 0.9251
# 4/4 [==============================] - 0s 9ms/step
#   Batch 17/42, d_real_loss: 0.6201, d_fake_loss: 0.6274,g_loss: 0.8724
# 4/4 [==============================] - 0s 9ms/step
#   Batch 18/42, d_real_loss: 0.6252, d_fake_loss: 0.6381,g_loss: 1.0084
# 4/4 [==============================] - 0s 9ms/step
#   Batch 19/42, d_real_loss: 0.6357, d_fake_loss: 0.6764,g_loss: 0.8721
# 4/4 [==============================] - 0s 9ms/step
#   Batch 20/42, d_real_loss: 0.6439, d_fake_loss: 0.7003,g_loss: 0.9340
# 4/4 [==============================] - 0s 9ms/step
#   Batch 21/42, d_real_loss: 0.6450, d_fake_loss: 0.6746,g_loss: 0.9743
# 4/4 [==============================] - 0s 9ms/step
#   Batch 22/42, d_real_loss: 0.6445, d_fake_loss: 0.6828,g_loss: 0.8033
# 4/4 [==============================] - 0s 9ms/step
#   Batch 23/42, d_real_loss: 0.6338, d_fake_loss: 0.6288,g_loss: 0.8849
# 4/4 [==============================] - 0s 10ms/step
#   Batch 24/42, d_real_loss: 0.6611, d_fake_loss: 0.6829,g_loss: 0.9424
# 4/4 [==============================] - 0s 10ms/step
#   Batch 25/42, d_real_loss: 0.6274, d_fake_loss: 0.6849,g_loss: 0.9344
# 4/4 [==============================] - 0s 9ms/step
#   Batch 26/42, d_real_loss: 0.6288, d_fake_loss: 0.6504,g_loss: 0.8485
# 4/4 [==============================] - 0s 10ms/step
#   Batch 27/42, d_real_loss: 0.6619, d_fake_loss: 0.6688,g_loss: 0.9292
# 4/4 [==============================] - 0s 10ms/step
#   Batch 28/42, d_real_loss: 0.6639, d_fake_loss: 0.6533,g_loss: 0.9570
# 4/4 [==============================] - 0s 9ms/step
#   Batch 29/42, d_real_loss: 0.6383, d_fake_loss: 0.6200,g_loss: 0.9370
# 4/4 [==============================] - 0s 9ms/step
#   Batch 30/42, d_real_loss: 0.6213, d_fake_loss: 0.7030,g_loss: 0.9625
# 4/4 [==============================] - 0s 9ms/step
#   Batch 31/42, d_real_loss: 0.6469, d_fake_loss: 0.6419,g_loss: 0.9369
# 4/4 [==============================] - 0s 10ms/step
#   Batch 32/42, d_real_loss: 0.6309, d_fake_loss: 0.6506,g_loss: 0.9239
# 4/4 [==============================] - 0s 9ms/step
#   Batch 33/42, d_real_loss: 0.6202, d_fake_loss: 0.6600,g_loss: 0.8938
# 4/4 [==============================] - 0s 8ms/step
#   Batch 34/42, d_real_loss: 0.6698, d_fake_loss: 0.6468,g_loss: 0.8772
# 4/4 [==============================] - 0s 8ms/step
#   Batch 35/42, d_real_loss: 0.6323, d_fake_loss: 0.6431,g_loss: 0.9102
# 4/4 [==============================] - 0s 10ms/step
#   Batch 36/42, d_real_loss: 0.6972, d_fake_loss: 0.6681,g_loss: 0.9467
# 4/4 [==============================] - 0s 9ms/step
#   Batch 37/42, d_real_loss: 0.6291, d_fake_loss: 0.6632,g_loss: 0.8260
# 4/4 [==============================] - 0s 8ms/step
#   Batch 38/42, d_real_loss: 0.6590, d_fake_loss: 0.6632,g_loss: 0.9672
# 4/4 [==============================] - 0s 9ms/step
#   Batch 39/42, d_real_loss: 0.6800, d_fake_loss: 0.6878,g_loss: 0.7333
# 4/4 [==============================] - 0s 9ms/step
#   Batch 40/42, d_real_loss: 0.6332, d_fake_loss: 0.6760,g_loss: 0.8183
# 4/4 [==============================] - 0s 9ms/step
#   Batch 41/42, d_real_loss: 0.6804, d_fake_loss: 0.6110,g_loss: 0.7790
# 4/4 [==============================] - 0s 9ms/step
#   Batch 42/42, d_real_loss: 0.6606, d_fake_loss: 0.6759,g_loss: 0.9437
# Epoch 50/10000
# 4/4 [==============================] - 0s 9ms/step
#   Batch 1/42, d_real_loss: 0.6405, d_fake_loss: 0.6424,g_loss: 0.8629
# 4/4 [==============================] - 0s 9ms/step
#   Batch 2/42, d_real_loss: 0.6258, d_fake_loss: 0.6684,g_loss: 0.7750
# 4/4 [==============================] - 0s 10ms/step
#   Batch 3/42, d_real_loss: 0.6275, d_fake_loss: 0.6736,g_loss: 0.8925
# 4/4 [==============================] - 0s 9ms/step
#   Batch 4/42, d_real_loss: 0.6351, d_fake_loss: 0.6398,g_loss: 0.8687
# 4/4 [==============================] - 0s 9ms/step
#   Batch 5/42, d_real_loss: 0.6427, d_fake_loss: 0.6375,g_loss: 0.9042
# 4/4 [==============================] - 0s 9ms/step
#   Batch 6/42, d_real_loss: 0.5959, d_fake_loss: 0.6070,g_loss: 0.9134
# 4/4 [==============================] - 0s 9ms/step
#   Batch 7/42, d_real_loss: 0.6361, d_fake_loss: 0.6738,g_loss: 0.9573
# 4/4 [==============================] - 0s 9ms/step
#   Batch 8/42, d_real_loss: 0.6307, d_fake_loss: 0.6416,g_loss: 0.8806
# 4/4 [==============================] - 0s 9ms/step
#   Batch 9/42, d_real_loss: 0.6525, d_fake_loss: 0.6865,g_loss: 0.9488
# 4/4 [==============================] - 0s 9ms/step
#   Batch 10/42, d_real_loss: 0.6403, d_fake_loss: 0.6631,g_loss: 0.9182
# 4/4 [==============================] - 0s 9ms/step
#   Batch 11/42, d_real_loss: 0.6530, d_fake_loss: 0.6938,g_loss: 0.8504
# 4/4 [==============================] - 0s 9ms/step
#   Batch 12/42, d_real_loss: 0.6400, d_fake_loss: 0.6891,g_loss: 0.9162
# 4/4 [==============================] - 0s 9ms/step
#   Batch 13/42, d_real_loss: 0.6504, d_fake_loss: 0.7104,g_loss: 0.8776
# 4/4 [==============================] - 0s 9ms/step
#   Batch 14/42, d_real_loss: 0.6147, d_fake_loss: 0.6919,g_loss: 0.8960
# 4/4 [==============================] - 0s 9ms/step
#   Batch 15/42, d_real_loss: 0.6993, d_fake_loss: 0.6815,g_loss: 0.9325
# 4/4 [==============================] - 0s 9ms/step
#   Batch 16/42, d_real_loss: 0.6186, d_fake_loss: 0.6657,g_loss: 0.8755
# 4/4 [==============================] - 0s 9ms/step
#   Batch 17/42, d_real_loss: 0.6768, d_fake_loss: 0.6502,g_loss: 0.8949
# 4/4 [==============================] - 0s 9ms/step
#   Batch 18/42, d_real_loss: 0.6454, d_fake_loss: 0.6283,g_loss: 0.9016
# 4/4 [==============================] - 0s 9ms/step
#   Batch 19/42, d_real_loss: 0.6766, d_fake_loss: 0.6703,g_loss: 0.8507
# 4/4 [==============================] - 0s 9ms/step
#   Batch 20/42, d_real_loss: 0.7119, d_fake_loss: 0.6593,g_loss: 0.8507
# 4/4 [==============================] - 0s 9ms/step
#   Batch 21/42, d_real_loss: 0.6618, d_fake_loss: 0.6328,g_loss: 0.9068
# 4/4 [==============================] - 0s 9ms/step
#   Batch 22/42, d_real_loss: 0.6519, d_fake_loss: 0.6480,g_loss: 0.8580
# 4/4 [==============================] - 0s 9ms/step
#   Batch 23/42, d_real_loss: 0.6205, d_fake_loss: 0.6276,g_loss: 0.8664
# 4/4 [==============================] - 0s 9ms/step
#   Batch 24/42, d_real_loss: 0.6595, d_fake_loss: 0.6665,g_loss: 0.9083
# 4/4 [==============================] - 0s 9ms/step
#   Batch 25/42, d_real_loss: 0.6174, d_fake_loss: 0.6384,g_loss: 0.9422
# 4/4 [==============================] - 0s 9ms/step
#   Batch 26/42, d_real_loss: 0.6713, d_fake_loss: 0.6459,g_loss: 0.9175
# 4/4 [==============================] - 0s 9ms/step
#   Batch 27/42, d_real_loss: 0.6044, d_fake_loss: 0.6965,g_loss: 0.8609
# 4/4 [==============================] - 0s 9ms/step
#   Batch 28/42, d_real_loss: 0.6333, d_fake_loss: 0.6441,g_loss: 0.8661
# 4/4 [==============================] - 0s 9ms/step
#   Batch 29/42, d_real_loss: 0.6265, d_fake_loss: 0.6582,g_loss: 0.8496
# 4/4 [==============================] - 0s 9ms/step
#   Batch 30/42, d_real_loss: 0.6083, d_fake_loss: 0.6323,g_loss: 1.0227
# 4/4 [==============================] - 0s 10ms/step
#   Batch 31/42, d_real_loss: 0.6510, d_fake_loss: 0.6553,g_loss: 0.9545
# 4/4 [==============================] - 0s 8ms/step
#   Batch 32/42, d_real_loss: 0.6619, d_fake_loss: 0.6564,g_loss: 0.9345
# 4/4 [==============================] - 0s 9ms/step
#   Batch 33/42, d_real_loss: 0.6258, d_fake_loss: 0.6815,g_loss: 0.9123
# 4/4 [==============================] - 0s 9ms/step
#   Batch 34/42, d_real_loss: 0.6416, d_fake_loss: 0.6813,g_loss: 1.0228
# 4/4 [==============================] - 0s 9ms/step
#   Batch 35/42, d_real_loss: 0.6591, d_fake_loss: 0.6277,g_loss: 0.8593
# 4/4 [==============================] - 0s 9ms/step
#   Batch 36/42, d_real_loss: 0.6372, d_fake_loss: 0.6732,g_loss: 0.9024
# 4/4 [==============================] - 0s 8ms/step
#   Batch 37/42, d_real_loss: 0.6145, d_fake_loss: 0.6820,g_loss: 0.9592
# 4/4 [==============================] - 0s 11ms/step
#   Batch 38/42, d_real_loss: 0.6287, d_fake_loss: 0.6491,g_loss: 0.9319
# 4/4 [==============================] - 0s 9ms/step
#   Batch 39/42, d_real_loss: 0.6953, d_fake_loss: 0.6345,g_loss: 0.8833
# 4/4 [==============================] - 0s 9ms/step
#   Batch 40/42, d_real_loss: 0.6330, d_fake_loss: 0.6789,g_loss: 0.7879
# 4/4 [==============================] - 0s 9ms/step
#   Batch 41/42, d_real_loss: 0.6822, d_fake_loss: 0.6409,g_loss: 0.9461
# 4/4 [==============================] - 0s 8ms/step
#   Batch 42/42, d_real_loss: 0.6161, d_fake_loss: 0.6247,g_loss: 0.9839
# Epoch 51/10000
# 4/4 [==============================] - 0s 9ms/step
#   Batch 1/42, d_real_loss: 0.6407, d_fake_loss: 0.6565,g_loss: 0.9278
# 4/4 [==============================] - 0s 10ms/step
#   Batch 2/42, d_real_loss: 0.6413, d_fake_loss: 0.6560,g_loss: 1.0284
# 4/4 [==============================] - 0s 9ms/step
#   Batch 3/42, d_real_loss: 0.6237, d_fake_loss: 0.6899,g_loss: 0.8722
# 4/4 [==============================] - 0s 9ms/step
#   Batch 4/42, d_real_loss: 0.6178, d_fake_loss: 0.6917,g_loss: 0.8814
# 4/4 [==============================] - 0s 9ms/step
#   Batch 5/42, d_real_loss: 0.6482, d_fake_loss: 0.6527,g_loss: 0.9243
# 4/4 [==============================] - 0s 9ms/step
#   Batch 6/42, d_real_loss: 0.6462, d_fake_loss: 0.6124,g_loss: 0.8466
# 4/4 [==============================] - 0s 9ms/step
#   Batch 7/42, d_real_loss: 0.6516, d_fake_loss: 0.6726,g_loss: 0.9840
# 4/4 [==============================] - 0s 9ms/step
#   Batch 8/42, d_real_loss: 0.6635, d_fake_loss: 0.6490,g_loss: 0.9478
# 4/4 [==============================] - 0s 9ms/step
#   Batch 9/42, d_real_loss: 0.6494, d_fake_loss: 0.6890,g_loss: 0.9610
# 4/4 [==============================] - 0s 9ms/step
#   Batch 10/42, d_real_loss: 0.6274, d_fake_loss: 0.6499,g_loss: 1.0066
# 4/4 [==============================] - 0s 10ms/step
#   Batch 11/42, d_real_loss: 0.6943, d_fake_loss: 0.6623,g_loss: 0.9663
# 4/4 [==============================] - 0s 9ms/step
#   Batch 12/42, d_real_loss: 0.6656, d_fake_loss: 0.6340,g_loss: 0.8701
# 4/4 [==============================] - 0s 9ms/step
#   Batch 13/42, d_real_loss: 0.6682, d_fake_loss: 0.6780,g_loss: 0.9103
# 4/4 [==============================] - 0s 9ms/step
#   Batch 14/42, d_real_loss: 0.6349, d_fake_loss: 0.6896,g_loss: 0.9786
# 4/4 [==============================] - 0s 9ms/step
#   Batch 15/42, d_real_loss: 0.6179, d_fake_loss: 0.6603,g_loss: 0.8924
# 4/4 [==============================] - 0s 9ms/step
#   Batch 16/42, d_real_loss: 0.6344, d_fake_loss: 0.6828,g_loss: 0.8614
# 4/4 [==============================] - 0s 9ms/step
#   Batch 17/42, d_real_loss: 0.6624, d_fake_loss: 0.6633,g_loss: 0.9426
# 4/4 [==============================] - 0s 9ms/step
#   Batch 18/42, d_real_loss: 0.6265, d_fake_loss: 0.6829,g_loss: 0.9074
# 4/4 [==============================] - 0s 9ms/step
#   Batch 19/42, d_real_loss: 0.6853, d_fake_loss: 0.6703,g_loss: 0.8501
# 4/4 [==============================] - 0s 9ms/step
#   Batch 20/42, d_real_loss: 0.6462, d_fake_loss: 0.6751,g_loss: 0.9105
# 4/4 [==============================] - 0s 9ms/step
#   Batch 21/42, d_real_loss: 0.6480, d_fake_loss: 0.6780,g_loss: 0.8525
# 4/4 [==============================] - 0s 9ms/step
# ...
# 4/4 [==============================] - 0s 9ms/step
#   Batch 20/42, d_real_loss: 0.6322, d_fake_loss: 0.6565,g_loss: 0.9087
# 4/4 [==============================] - 0s 9ms/step
#   Batch 21/42, d_real_loss: 0.6647, d_fake_loss: 0.6883,g_loss: 0.9089
# 4/4 [==============================] - 0s 10ms/step
#   Batch 22/42, d_real_loss: 0.6316, d_fake_loss: 0.6469,g_loss: 0.8532
# 4/4 [==============================] - 0s 9ms/step
#   Batch 23/42, d_real_loss: 0.6920, d_fake_loss: 0.6880,g_loss: 0.8584
# 4/4 [==============================] - 0s 9ms/step
#   Batch 24/42, d_real_loss: 0.6494, d_fake_loss: 0.6910,g_loss: 0.9533
# 4/4 [==============================] - 0s 9ms/step
#   Batch 25/42, d_real_loss: 0.6347, d_fake_loss: 0.6659,g_loss: 0.9268
# 4/4 [==============================] - 0s 9ms/step
#   Batch 26/42, d_real_loss: 0.6432, d_fake_loss: 0.6363,g_loss: 0.9049
# 4/4 [==============================] - 0s 9ms/step
#   Batch 27/42, d_real_loss: 0.6273, d_fake_loss: 0.6974,g_loss: 0.9275
# 4/4 [==============================] - 0s 9ms/step
#   Batch 28/42, d_real_loss: 0.6184, d_fake_loss: 0.6437,g_loss: 0.9578
# 4/4 [==============================] - 0s 9ms/step
#   Batch 29/42, d_real_loss: 0.6390, d_fake_loss: 0.6548,g_loss: 1.0356
# 4/4 [==============================] - 0s 9ms/step
#   Batch 30/42, d_real_loss: 0.6808, d_fake_loss: 0.6576,g_loss: 0.9298
# 4/4 [==============================] - 0s 9ms/step
#   Batch 31/42, d_real_loss: 0.6781, d_fake_loss: 0.6798,g_loss: 0.9460
# 4/4 [==============================] - 0s 9ms/step
#   Batch 32/42, d_real_loss: 0.6516, d_fake_loss: 0.6905,g_loss: 0.9768
# 4/4 [==============================] - 0s 9ms/step
#   Batch 33/42, d_real_loss: 0.6766, d_fake_loss: 0.6420,g_loss: 0.9579
# 4/4 [==============================] - 0s 9ms/step
#   Batch 34/42, d_real_loss: 0.6086, d_fake_loss: 0.6430,g_loss: 0.8806
# 4/4 [==============================] - 0s 9ms/step
#   Batch 35/42, d_real_loss: 0.6506, d_fake_loss: 0.6758,g_loss: 0.9107
# 4/4 [==============================] - 0s 9ms/step
#   Batch 36/42, d_real_loss: 0.6084, d_fake_loss: 0.6181,g_loss: 0.9496
# 4/4 [==============================] - 0s 9ms/step
#   Batch 37/42, d_real_loss: 0.6620, d_fake_loss: 0.6525,g_loss: 0.8916
# 4/4 [==============================] - 0s 9ms/step
#   Batch 38/42, d_real_loss: 0.6057, d_fake_loss: 0.6451,g_loss: 0.9445
# 4/4 [==============================] - 0s 9ms/step
#   Batch 39/42, d_real_loss: 0.6395, d_fake_loss: 0.6620,g_loss: 0.8315
# 4/4 [==============================] - 0s 9ms/step
#   Batch 40/42, d_real_loss: 0.6341, d_fake_loss: 0.6970,g_loss: 0.9850
# 4/4 [==============================] - 0s 9ms/step
#   Batch 41/42, d_real_loss: 0.6568, d_fake_loss: 0.6318,g_loss: 1.0293
# 4/4 [==============================] - 0s 9ms/step
#   Batch 42/42, d_real_loss: 0.6427, d_fake_loss: 0.6764,g_loss: 0.9272
# Epoch 718/10000
# 4/4 [==============================] - 0s 9ms/step
#   Batch 1/42, d_real_loss: 0.6334, d_fake_loss: 0.6447,g_loss: 0.9607
# 4/4 [==============================] - 0s 9ms/step
#   Batch 2/42, d_real_loss: 0.6789, d_fake_loss: 0.6877,g_loss: 0.9452
# 4/4 [==============================] - 0s 9ms/step
#   Batch 3/42, d_real_loss: 0.6401, d_fake_loss: 0.6362,g_loss: 0.8987
# 4/4 [==============================] - 0s 8ms/step
#   Batch 4/42, d_real_loss: 0.6604, d_fake_loss: 0.6508,g_loss: 0.9887
# 4/4 [==============================] - 0s 8ms/step
#   Batch 5/42, d_real_loss: 0.6433, d_fake_loss: 0.6244,g_loss: 0.8594
# 4/4 [==============================] - 0s 9ms/step
#   Batch 6/42, d_real_loss: 0.6493, d_fake_loss: 0.6692,g_loss: 0.8624
# 4/4 [==============================] - 0s 10ms/step
#   Batch 7/42, d_real_loss: 0.6483, d_fake_loss: 0.6298,g_loss: 0.9129
# 4/4 [==============================] - 0s 9ms/step
#   Batch 8/42, d_real_loss: 0.6294, d_fake_loss: 0.6377,g_loss: 0.9771
# 4/4 [==============================] - 0s 9ms/step
#   Batch 9/42, d_real_loss: 0.6590, d_fake_loss: 0.6771,g_loss: 0.8882
# 4/4 [==============================] - 0s 8ms/step
#   Batch 10/42, d_real_loss: 0.6618, d_fake_loss: 0.6803,g_loss: 0.9029
# 4/4 [==============================] - 0s 11ms/step
#   Batch 11/42, d_real_loss: 0.6273, d_fake_loss: 0.6631,g_loss: 0.8924
# 4/4 [==============================] - 0s 9ms/step
#   Batch 12/42, d_real_loss: 0.6783, d_fake_loss: 0.6540,g_loss: 0.9658
# 4/4 [==============================] - 0s 9ms/step
#   Batch 13/42, d_real_loss: 0.6677, d_fake_loss: 0.6719,g_loss: 0.9113
# 4/4 [==============================] - 0s 9ms/step
#   Batch 14/42, d_real_loss: 0.6522, d_fake_loss: 0.6533,g_loss: 0.9578
# 4/4 [==============================] - 0s 8ms/step
#   Batch 15/42, d_real_loss: 0.6383, d_fake_loss: 0.6706,g_loss: 0.8994
# 4/4 [==============================] - 0s 11ms/step
#   Batch 16/42, d_real_loss: 0.6360, d_fake_loss: 0.6624,g_loss: 0.8923
# 4/4 [==============================] - 0s 8ms/step
#   Batch 17/42, d_real_loss: 0.6203, d_fake_loss: 0.6930,g_loss: 0.8932
# 4/4 [==============================] - 0s 9ms/step
#   Batch 18/42, d_real_loss: 0.6704, d_fake_loss: 0.6812,g_loss: 0.9396
# 4/4 [==============================] - 0s 9ms/step
#   Batch 19/42, d_real_loss: 0.6257, d_fake_loss: 0.6415,g_loss: 1.0066
# 4/4 [==============================] - 0s 9ms/step
#   Batch 20/42, d_real_loss: 0.6235, d_fake_loss: 0.6469,g_loss: 0.7920
# 4/4 [==============================] - 0s 9ms/step
#   Batch 21/42, d_real_loss: 0.6411, d_fake_loss: 0.6806,g_loss: 0.9133
# 4/4 [==============================] - 0s 9ms/step
#   Batch 22/42, d_real_loss: 0.6522, d_fake_loss: 0.6790,g_loss: 1.0185
# 4/4 [==============================] - 0s 9ms/step
#   Batch 23/42, d_real_loss: 0.6353, d_fake_loss: 0.6463,g_loss: 0.9915
# 4/4 [==============================] - 0s 9ms/step
#   Batch 24/42, d_real_loss: 0.6509, d_fake_loss: 0.6766,g_loss: 0.9533
# 4/4 [==============================] - 0s 9ms/step
#   Batch 25/42, d_real_loss: 0.6508, d_fake_loss: 0.6295,g_loss: 0.9433
# 4/4 [==============================] - 0s 9ms/step
#   Batch 26/42, d_real_loss: 0.6373, d_fake_loss: 0.6559,g_loss: 0.9116
# 4/4 [==============================] - 0s 9ms/step
#   Batch 27/42, d_real_loss: 0.6198, d_fake_loss: 0.6581,g_loss: 0.9839
# 4/4 [==============================] - 0s 9ms/step
#   Batch 28/42, d_real_loss: 0.7358, d_fake_loss: 0.6276,g_loss: 0.8003
# 4/4 [==============================] - 0s 9ms/step
#   Batch 29/42, d_real_loss: 0.6405, d_fake_loss: 0.6578,g_loss: 0.8463
# 4/4 [==============================] - 0s 9ms/step
#   Batch 30/42, d_real_loss: 0.6297, d_fake_loss: 0.6536,g_loss: 0.9412
# 4/4 [==============================] - 0s 9ms/step
#   Batch 31/42, d_real_loss: 0.6380, d_fake_loss: 0.6544,g_loss: 0.9469
# 4/4 [==============================] - 0s 9ms/step
#   Batch 32/42, d_real_loss: 0.6567, d_fake_loss: 0.6423,g_loss: 0.9164
# 4/4 [==============================] - 0s 9ms/step
#   Batch 33/42, d_real_loss: 0.6484, d_fake_loss: 0.6518,g_loss: 0.9704
# 4/4 [==============================] - 0s 9ms/step
#   Batch 34/42, d_real_loss: 0.6215, d_fake_loss: 0.6493,g_loss: 0.9656
# 4/4 [==============================] - 0s 9ms/step
#   Batch 35/42, d_real_loss: 0.6669, d_fake_loss: 0.6372,g_loss: 0.9124
# 4/4 [==============================] - 0s 9ms/step
#   Batch 36/42, d_real_loss: 0.6488, d_fake_loss: 0.6777,g_loss: 0.8822
# 4/4 [==============================] - 0s 9ms/step
#   Batch 37/42, d_real_loss: 0.6315, d_fake_loss: 0.6538,g_loss: 0.9007
# 4/4 [==============================] - 0s 9ms/step
#   Batch 38/42, d_real_loss: 0.7058, d_fake_loss: 0.6610,g_loss: 0.8063
# 4/4 [==============================] - 0s 9ms/step
#   Batch 39/42, d_real_loss: 0.6397, d_fake_loss: 0.6853,g_loss: 0.8601
# 4/4 [==============================] - 0s 9ms/step
#   Batch 40/42, d_real_loss: 0.6437, d_fake_loss: 0.6796,g_loss: 0.7885
# 4/4 [==============================] - 0s 9ms/step
#   Batch 41/42, d_real_loss: 0.6163, d_fake_loss: 0.6297,g_loss: 0.8775
# 4/4 [==============================] - 0s 9ms/step
#   Batch 42/42, d_real_loss: 0.6699, d_fake_loss: 0.6817,g_loss: 0.9715
# Epoch 719/10000
# 4/4 [==============================] - 0s 9ms/step
#   Batch 1/42, d_real_loss: 0.6073, d_fake_loss: 0.7041,g_loss: 0.8860
# 4/4 [==============================] - 0s 10ms/step
#   Batch 2/42, d_real_loss: 0.6275, d_fake_loss: 0.6337,g_loss: 0.8544
# 4/4 [==============================] - 0s 9ms/step
#   Batch 3/42, d_real_loss: 0.6369, d_fake_loss: 0.6139,g_loss: 0.9410
# 4/4 [==============================] - 0s 9ms/step
#   Batch 4/42, d_real_loss: 0.6242, d_fake_loss: 0.7220,g_loss: 0.8511
# 4/4 [==============================] - 0s 9ms/step
#   Batch 5/42, d_real_loss: 0.6113, d_fake_loss: 0.6766,g_loss: 0.8695
# 4/4 [==============================] - 0s 9ms/step
#   Batch 6/42, d_real_loss: 0.6680, d_fake_loss: 0.6464,g_loss: 0.7413
# 4/4 [==============================] - 0s 9ms/step
#   Batch 7/42, d_real_loss: 0.6198, d_fake_loss: 0.6654,g_loss: 0.8597
# 4/4 [==============================] - 0s 9ms/step
#   Batch 8/42, d_real_loss: 0.6243, d_fake_loss: 0.7068,g_loss: 0.8357
# 4/4 [==============================] - 0s 9ms/step
#   Batch 9/42, d_real_loss: 0.6067, d_fake_loss: 0.7082,g_loss: 0.9777
# 4/4 [==============================] - 0s 9ms/step
#   Batch 10/42, d_real_loss: 0.6336, d_fake_loss: 0.6730,g_loss: 0.8580
# 4/4 [==============================] - 0s 9ms/step
#   Batch 11/42, d_real_loss: 0.6498, d_fake_loss: 0.6311,g_loss: 0.8487
# 4/4 [==============================] - 0s 9ms/step
#   Batch 12/42, d_real_loss: 0.6314, d_fake_loss: 0.6104,g_loss: 1.0231
# 4/4 [==============================] - 0s 9ms/step
#   Batch 13/42, d_real_loss: 0.6495, d_fake_loss: 0.6555,g_loss: 0.9204
# 4/4 [==============================] - 0s 9ms/step
#   Batch 14/42, d_real_loss: 0.6475, d_fake_loss: 0.6589,g_loss: 1.0409
# 4/4 [==============================] - 0s 9ms/step
#   Batch 15/42, d_real_loss: 0.6654, d_fake_loss: 0.6730,g_loss: 0.9394
# 4/4 [==============================] - 0s 10ms/step
#   Batch 16/42, d_real_loss: 0.6431, d_fake_loss: 0.6744,g_loss: 0.8381
# 4/4 [==============================] - 0s 9ms/step
#   Batch 17/42, d_real_loss: 0.6784, d_fake_loss: 0.6685,g_loss: 0.9189
# 4/4 [==============================] - 0s 9ms/step
#   Batch 18/42, d_real_loss: 0.6609, d_fake_loss: 0.6428,g_loss: 0.8244
# 4/4 [==============================] - 0s 8ms/step
#   Batch 19/42, d_real_loss: 0.6181, d_fake_loss: 0.6614,g_loss: 0.8986
# 4/4 [==============================] - 0s 8ms/step
#   Batch 20/42, d_real_loss: 0.6159, d_fake_loss: 0.6673,g_loss: 0.9014
# 4/4 [==============================] - 0s 9ms/step
#   Batch 21/42, d_real_loss: 0.6423, d_fake_loss: 0.6577,g_loss: 0.9052
# 4/4 [==============================] - 0s 9ms/step
#   Batch 22/42, d_real_loss: 0.6643, d_fake_loss: 0.6665,g_loss: 0.8709
# 4/4 [==============================] - 0s 9ms/step
#   Batch 23/42, d_real_loss: 0.6158, d_fake_loss: 0.6333,g_loss: 0.9293
# 4/4 [==============================] - 0s 9ms/step
#   Batch 24/42, d_real_loss: 0.6132, d_fake_loss: 0.6400,g_loss: 1.0125
# 4/4 [==============================] - 0s 9ms/step
#   Batch 25/42, d_real_loss: 0.6428, d_fake_loss: 0.6663,g_loss: 0.8910
# 4/4 [==============================] - 0s 9ms/step
#   Batch 26/42, d_real_loss: 0.6392, d_fake_loss: 0.6208,g_loss: 0.9917
# 4/4 [==============================] - 0s 9ms/step
#   Batch 27/42, d_real_loss: 0.6527, d_fake_loss: 0.6247,g_loss: 0.9456
# 4/4 [==============================] - 0s 9ms/step
#   Batch 28/42, d_real_loss: 0.6519, d_fake_loss: 0.6809,g_loss: 1.0413
# 4/4 [==============================] - 0s 9ms/step
#   Batch 29/42, d_real_loss: 0.6413, d_fake_loss: 0.7099,g_loss: 0.9499
# 4/4 [==============================] - 0s 8ms/step
#   Batch 30/42, d_real_loss: 0.6344, d_fake_loss: 0.6661,g_loss: 0.9255
# 4/4 [==============================] - 0s 8ms/step
#   Batch 31/42, d_real_loss: 0.6579, d_fake_loss: 0.6543,g_loss: 0.9726
# 4/4 [==============================] - 0s 8ms/step
#   Batch 32/42, d_real_loss: 0.6278, d_fake_loss: 0.6699,g_loss: 0.8941
# 4/4 [==============================] - 0s 9ms/step
#   Batch 33/42, d_real_loss: 0.6387, d_fake_loss: 0.7188,g_loss: 0.9862
# 4/4 [==============================] - 0s 9ms/step
#   Batch 34/42, d_real_loss: 0.6437, d_fake_loss: 0.6447,g_loss: 0.8329
# 4/4 [==============================] - 0s 9ms/step
#   Batch 35/42, d_real_loss: 0.6254, d_fake_loss: 0.6351,g_loss: 0.9029
# 4/4 [==============================] - 0s 9ms/step
#   Batch 36/42, d_real_loss: 0.6145, d_fake_loss: 0.6612,g_loss: 0.9642
# 4/4 [==============================] - 0s 9ms/step
#   Batch 37/42, d_real_loss: 0.6281, d_fake_loss: 0.6477,g_loss: 0.9491
# 4/4 [==============================] - 0s 9ms/step
#   Batch 38/42, d_real_loss: 0.6350, d_fake_loss: 0.6834,g_loss: 1.0650
# 4/4 [==============================] - 0s 9ms/step
#   Batch 39/42, d_real_loss: 0.6509, d_fake_loss: 0.6474,g_loss: 0.8621
# 4/4 [==============================] - 0s 9ms/step
#   Batch 40/42, d_real_loss: 0.6584, d_fake_loss: 0.6854,g_loss: 0.9380
# 4/4 [==============================] - 0s 9ms/step
#   Batch 41/42, d_real_loss: 0.6099, d_fake_loss: 0.6481,g_loss: 0.9459
# 4/4 [==============================] - 0s 9ms/step
#   Batch 42/42, d_real_loss: 0.6419, d_fake_loss: 0.5952,g_loss: 0.8367
# Epoch 720/10000
# 4/4 [==============================] - 0s 11ms/step
#   Batch 1/42, d_real_loss: 0.6359, d_fake_loss: 0.6538,g_loss: 1.0206
# 4/4 [==============================] - 0s 10ms/step
#   Batch 2/42, d_real_loss: 0.6514, d_fake_loss: 0.6422,g_loss: 0.9310
# 4/4 [==============================] - 0s 9ms/step
#   Batch 3/42, d_real_loss: 0.6080, d_fake_loss: 0.6724,g_loss: 1.0104
# 4/4 [==============================] - 0s 8ms/step
#   Batch 4/42, d_real_loss: 0.6597, d_fake_loss: 0.6339,g_loss: 1.0056
# 4/4 [==============================] - 0s 8ms/step
#   Batch 5/42, d_real_loss: 0.6767, d_fake_loss: 0.6263,g_loss: 1.0126
# 4/4 [==============================] - 0s 10ms/step
#   Batch 6/42, d_real_loss: 0.6591, d_fake_loss: 0.6707,g_loss: 0.9745
# 4/4 [==============================] - 0s 8ms/step
#   Batch 7/42, d_real_loss: 0.6415, d_fake_loss: 0.6902,g_loss: 0.9263
# 4/4 [==============================] - 0s 9ms/step
#   Batch 8/42, d_real_loss: 0.6621, d_fake_loss: 0.6724,g_loss: 0.9270
# 4/4 [==============================] - 0s 11ms/step
#   Batch 9/42, d_real_loss: 0.6388, d_fake_loss: 0.6647,g_loss: 0.9648
# 4/4 [==============================] - 0s 8ms/step
#   Batch 10/42, d_real_loss: 0.6426, d_fake_loss: 0.6752,g_loss: 0.8915
# 4/4 [==============================] - 0s 10ms/step
#   Batch 11/42, d_real_loss: 0.6730, d_fake_loss: 0.6238,g_loss: 0.9107
# 4/4 [==============================] - 0s 10ms/step
#   Batch 12/42, d_real_loss: 0.6303, d_fake_loss: 0.6387,g_loss: 0.8827
# 4/4 [==============================] - 0s 9ms/step
#   Batch 13/42, d_real_loss: 0.6395, d_fake_loss: 0.7020,g_loss: 0.8933
# 4/4 [==============================] - 0s 9ms/step
#   Batch 14/42, d_real_loss: 0.6373, d_fake_loss: 0.6532,g_loss: 0.9057
# 4/4 [==============================] - 0s 9ms/step
#   Batch 15/42, d_real_loss: 0.6916, d_fake_loss: 0.7031,g_loss: 0.8972
# 4/4 [==============================] - 0s 9ms/step
#   Batch 16/42, d_real_loss: 0.6422, d_fake_loss: 0.6843,g_loss: 0.9971
# 4/4 [==============================] - 0s 9ms/step
#   Batch 17/42, d_real_loss: 0.7001, d_fake_loss: 0.6628,g_loss: 0.9587
# 4/4 [==============================] - 0s 9ms/step
#   Batch 18/42, d_real_loss: 0.6361, d_fake_loss: 0.5808,g_loss: 0.9230
# 4/4 [==============================] - 0s 9ms/step
#   Batch 19/42, d_real_loss: 0.6454, d_fake_loss: 0.6737,g_loss: 0.9242
# 4/4 [==============================] - 0s 9ms/step
#   Batch 20/42, d_real_loss: 0.6342, d_fake_loss: 0.6773,g_loss: 0.9183
# 4/4 [==============================] - 0s 9ms/step
#   Batch 21/42, d_real_loss: 0.6464, d_fake_loss: 0.6719,g_loss: 0.9466
# 4/4 [==============================] - 0s 9ms/step
#   Batch 22/42, d_real_loss: 0.6608, d_fake_loss: 0.6580,g_loss: 0.8985
# 4/4 [==============================] - 0s 9ms/step
#   Batch 23/42, d_real_loss: 0.6326, d_fake_loss: 0.6581,g_loss: 0.8099
# 4/4 [==============================] - 0s 9ms/step

# %%
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples, n_class):
 # generate points in the latent space
  x_input = randn(latent_dim * n_samples)
 # reshape into a batch of inputs for the network
  z_input = x_input.reshape(n_samples, latent_dim)
 # generate labels
  labels = asarray([n_class for _ in range(n_samples)])
  return [z_input, labels]

# create and save a plot of generated images
def save_plot(examples, n_examples):
    # Calculate the number of rows and columns for subplot arrangement
    n_rows = int(sqrt(n_examples))
    n_cols = int(sqrt(n_examples))

    # Plot images
    plt.figure(figsize=(8, 8))  # Adjust the figure size if needed
    for i in range(n_examples):
        # Define subplot
        plt.subplot(n_rows, n_cols, 1 + i)
        # Turn off axis
        plt.axis('off')
        # Plot raw pixel data
        plt.imshow(examples[i, :, :, 0], cmap='gray_r')

    # Show the plot
    plt.show()


# load model
model =load_model('generator_model.h5')
latent_dim = 100
n_examples = 100 # must be a square
n_class = 0 # sneaker
# generate images
latent_points, labels = generate_latent_points(latent_dim, n_examples, n_class)
# generate images
X  = model.predict([latent_points, labels])
# scale from [-1,1] to [0,1]
X = (X + 1) / 2.0
# plot the result
save_plot(X, n_examples)
